# %% [markdown]
# # Lesson 6: APIs to use AI models
#
#
# # 第 6 课：使用 AI 模型的 API

# %% [markdown]
# In this lesson, you will learn how to use the OpenAI API. You'll also see how the `print_llm_response` and `get_llm_response` functions you have been using work to pass your prompt to the OpenAI API and retrieve the response.
#
# 在本课程中，您将学习如何使用 OpenAI API。您还将看到您一直使用的“print_llm_response”和“get_llm_response”函数如何将提示传递给 OpenAI API 并检索响应。
#
# As always, you'll start by loading some functions you need:
#
#
# 与往常一样，您将首先加载一些您需要的函数：

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %% [markdown]
# Note the `openai` package, which you are using for the first time! The `OpenAI` function here is what enables the connect in Python to the chatbot. Check out the [OpenAI documentation](https://platform.openai.com/docs/api-reference/introduction) if you want to learn more!
#
# 请注意“openai”包，这是您第一次使用！这里的“OpenAI”函数可以在 Python 中连接到聊天机器人。如果您想了解更多信息，请查看 [OpenAI 文档](https://platform.openai.com/docs/api-reference/introduction)！
#
# **Note:** If you want to install this on your own computer, you would run `!pip install openai`. But it's already installed here for you.
#
#
# **注意：** 如果您想在自己的计算机上安装它，您可以运行 `!pip install openai`。但它已经为您安装在这里了。

# %%
def get_llm_response(prompt):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system", 
                "content": "You are a helpful but terse AI assistant who gets straight to the point."
            },
            {"role": "user", "content": prompt},
        ],
        temperature=0.0,
    )
    response = completion.choices[0].message.content
    return response

# %% [markdown]
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>Use the Chatbot</b>:
#
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>使用聊天机器人</b>：
# <br><br>
#
# <br><br>
# Explain what each line of this function does:
#
# 解释一下这个函数的每一行的作用：
# <br><br>
#
# <br><br>
# def get_llm_response(prompt):<br>
#
# def get_llm_response(提示):<br>
# &nbsp &nbsp &nbsp completion = client.chat.completions.create(<br>
#
# &nbsp &nbsp &nbsp 完成 = client.chat.completions.create(<br>
# &nbsp &nbsp &nbsp model="gpt-4o-mini",<br>
#
# &nbsp &nbsp &nbsp model="gpt-4o-mini",<br>
# &nbsp &nbsp &nbspmessages=[<br>
#
# &nbsp &nbsp &nbspmessages=[<br>
# &nbsp &nbsp &nbsp&nbsp{<br>
#
# &nbsp &nbsp &nbsp&nbsp{<br>
# &nbsp &nbsp &nbsp&nbsp&nbsp"role": "system",<br>
#
# &nbsp &nbsp &nbsp &nbsp&nbsp&nbsp"role": "system",<br>
# &nbsp &nbsp &nbsp&nbsp&nbsp"content": "You are a helpful but terse AI assistant who gets straight to the point.",<br>
#
# &nbsp &nbsp&nbsp&nbsp"content": "你是一位乐于助人、简洁明了的人工智能助手。",<br>
# &nbsp &nbsp &nbsp&nbsp&nbsp},<br>
#
# &nbsp &nbsp&nbsp&nbsp},<br>
# &nbsp &nbsp &nbsp&nbsp{"role": "user", "content": prompt},<br>
#
# &nbsp&nbsp{"角色": "用户", "内容": 提示},<br>
# &nbsp &nbsp &nbsp&nbsp],<br>
#
# &nbsp &nbsp&nbsp],<br>
# &nbsp &nbsp &nbsptemperature=0.0,<br>
#
# &nbsp &nbsp温度=0.0,<br>
# &nbsp &nbsp &nbsp)<br>
#
# &nbsp &nbsp &nbsp)<br>
# &nbsp &nbsp &nbspresponse = completion.choices[0].message.content<br>
#
# &nbsp &nbsp &nbspresponse =completion.choices[0].message.content<br>
# &nbspreturn response<br>
#
# &nbspre返回响应<br>
# </p>

# %% [markdown]
# ## Setting up the API key
#
# ## 设置 API 密钥
#
# To use the OpenAI API service you need an API key. Run the following code to set up the key in this learning environment:
#
#
# 要使用 OpenAI API 服务，您需要 API 密钥。运行以下代码在此学习环境中设置密钥：

# %%
# Get the OpenAI API key from the .env file
load_dotenv('.env', override=True)
# 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
openai_api_key = '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'
# openai_api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key = openai_api_key)

# %% [markdown]
# ## Revisiting ```get_llm_response```
#
#
# ## 重新访问 ```get_llm_response```

# %% [markdown]
# Here is the code you saw in the slides to define the ```get_llm_response``` function:
#
#
# 以下是您在幻灯片中看到的定义“get_llm_response”函数的代码：

# %%
def get_llm_response(prompt):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are an AI assistant.",
            },
            {"role": "user", "content": prompt},
        ],
        temperature=0.0,
    )
    response = completion.choices[0].message.content
    return response

# %% [markdown]
# You can now use this function to ask a question to an LLM:
#
#
# 您现在可以使用此功能向法学硕士提问：

# %%
prompt = "What is the capital of France?"
response = get_llm_response(prompt)
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 prompt = "What is the capital of France?"
# ----> 2 response = get_llm_response(prompt)
#       3 print(response)
#
# Cell In[7], line 2, in get_llm_response(prompt)
#       1 def get_llm_response(prompt):
# ----> 2     completion = client.chat.completions.create(
#       3         model="gpt-4o-mini",
#       4         messages=[
#       5             {
#       6                 "role": "system",
#       7                 "content": "You are an AI assistant.",
#       8             },
#       9             {"role": "user", "content": prompt},
#      10         ],
#      11         temperature=0.0,
#      12     )
#      13     response = completion.choices[0].message.content
#      14     return response
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/resources/chat/completions.py:850, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     808 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     809 def create(
#     810     self,
#    (...)
#     847     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     848 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     849     validate_response_format(response_format)
# --> 850     return self._post(
#     851         "/chat/completions",
#     852         body=maybe_transform(
#     853             {
#     854                 "messages": messages,
#     855                 "model": model,
#     856                 "audio": audio,
#     857                 "frequency_penalty": frequency_penalty,
#     858                 "function_call": function_call,
#     859                 "functions": functions,
#     860                 "logit_bias": logit_bias,
#     861                 "logprobs": logprobs,
#     862                 "max_completion_tokens": max_completion_tokens,
#     863                 "max_tokens": max_tokens,
#     864                 "metadata": metadata,
#     865                 "modalities": modalities,
#     866                 "n": n,
#     867                 "parallel_tool_calls": parallel_tool_calls,
#     868                 "prediction": prediction,
#     869                 "presence_penalty": presence_penalty,
#     870                 "reasoning_effort": reasoning_effort,
#     871                 "response_format": response_format,
#     872                 "seed": seed,
#     873                 "service_tier": service_tier,
#     874                 "stop": stop,
#     875                 "store": store,
#     876                 "stream": stream,
#     877                 "stream_options": stream_options,
#     878                 "temperature": temperature,
#     879                 "tool_choice": tool_choice,
#     880                 "tools": tools,
#     881                 "top_logprobs": top_logprobs,
#     882                 "top_p": top_p,
#     883                 "user": user,
#     884             },
#     885             completion_create_params.CompletionCreateParams,
#     886         ),
#     887         options=make_request_options(
#     888             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     889         ),
#     890         cast_to=ChatCompletion,
#     891         stream=stream or False,
#     892         stream_cls=Stream[ChatCompletionChunk],
#     893     )
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017 log.debug("Encountered Exception", exc_info=True)
#    1019 if remaining_retries > 0:
# -> 1020     return self._retry_request(
#    1021         input_options,
#    1022         cast_to,
#    1023         retries_taken=retries_taken,
#    1024         stream=stream,
#    1025         stream_cls=stream_cls,
#    1026         response_headers=None,
#    1027     )
#    1029 log.debug("Raising connection error")
#    1030 raise APIConnectionError(request=request) from err
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1049, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1047 if remaining_retries > 0 and self._should_retry(err.response):
#    1048     err.response.close()
# -> 1049     return self._retry_request(
#    1050         input_options,
#    1051         cast_to,
#    1052         retries_taken=retries_taken,
#    1053         response_headers=err.response.headers,
#    1054         stream=stream,
#    1055         stream_cls=stream_cls,
#    1056     )
#    1058 # If the response is streamed then we need to explicitly read the response
#    1059 # to completion before attempting to access the response text.
#    1060 if not err.response.is_closed:
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1098, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1094 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1095 # different thread if necessary.
#    1096 time.sleep(timeout)
# -> 1098 return self._request(
#    1099     options=options,
#    1100     cast_to=cast_to,
#    1101     retries_taken=retries_taken + 1,
#    1102     stream=stream,
#    1103     stream_cls=stream_cls,
#    1104 )
#
# File ~/miniconda3/envs/ailearn/lib/python3.11/site-packages/openai/_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## Modifying the system message to change the LLM behavior
#
# ## 修改系统消息以更改 LLM 行为
#
# Try changing/adding details in the "content" of the system message to change the LLM response
#
# 尝试更改/添加系统消息“内容”中的详细信息以更改 LLM 响应
# * For example, "You are a sarcastic AI assistant."
#
# * 例如，“你是一个讽刺的人工智能助手。”
# * Be sure to run the function cell each time you change the system message before you prompt the LLM.
#
#
# * 每次在提示 LLM 之前更改系统消息时，请务必运行该功能单元。

# %%
def get_llm_response(prompt):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are an AI assistant.", # change this instruction!
            },
            {"role": "user", "content": prompt},
        ],
        temperature=0.0,
    )
    response = completion.choices[0].message.content
    return response

# %% [markdown]
# Now give your prompt to the LLM:
#
#
# 现在向 LLM 提出您的提示：

# %%
prompt = "What is the capital of France?"
response = get_llm_response(prompt)
print(response)

# %% [markdown]
# Vary the system prompt a few times to see the behavior change!
#
#
# 改变系统提示几次以查看行为变化！

# %% [markdown]
# ## Modify the temperature to change the randomness of the output
#
# ## 修改温度来改变输出的随机性
#
# Try changing the temperature value to make the response of the model more random and different each time
#
# 尝试改变温度值，使模型的响应更加随机且每次都不同
# * For example, set the temperature to 1.0 or 0.7 and see what happens
#
# * 例如，将温度设置为 1.0 或 0.7，看看会发生什么
# * Be sure to run the function cell each time you change the temperature before you prompt the LLM.
#
#
# * 在提示 LLM 之前，请确保每次更改温度时都运行函数单元。

# %%
def get_llm_response(prompt):
    completion = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": "You are an AI assistant.", 
            },
            {"role": "user", "content": prompt},
        ],
        temperature=0.0, # change this to a value between 0 and 2
    )
    response = completion.choices[0].message.content
    return response

# %% [markdown]
# Now give your prompt to the LLM
#
#
# 现在向 LLM 提出您的提示

# %%
prompt = "What is the capital of France?"
response = get_llm_response(prompt)
print(response)

# %% [markdown]
# Change the temperature to a value greater than 0 and run the prompt cell a few times to see the response change!
#
#
# 将温度更改为大于 0 的值并运行提示单元几次以查看响应变化！

# %% [markdown]
# ## Using LLMs through the `aisetup` package
#
# ## 通过 `aisetup` 包使用 LLM
#
# If you have installed aisetup on your own computer, you'll need to run an extra line of code to get your own API key into the notebook and accessible to the `print_llm_response` and `get_llm_response` functions:
#
#
# 如果您在自己的计算机上安装了 aisetup，则需要运行额外的代码行以将自己的 API 密钥放入笔记本中，并可访问“print_llm_response”和“get_llm_response”函数：

# %%
from aisetup import authenticate, print_llm_response, get_llm_response

authenticate("YOUR API KEY HERE")

# Print the LLM response
print_llm_response("What is the capital of France")

# Store the LLM response as a variable and then print
response = get_llm_response("What is the capital of France")
print(response)

# %% [markdown]
# **Note:** Please follow best practices and **don't** expose your API KEY in any code you write!
#
# **注意：**请遵循最佳实践，并且**不要**在您编写的任何代码中暴露您的 API 密钥！
#
# You can try this method instead:
#
#
# 您可以尝试以下方法：

# %%
from aisetup import authenticate, print_llm_response, get_llm_response
from dotenv import load_dotenv
import os

load_dotenv('.env', override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
authenticate(openai_api_key)

# Print the LLM response
print_llm_response("What is the capital of France")

# Store the LLM response as a variable and then print
response = print_llm_response("What is the capital of France")
print(response)

# %% [markdown]
# ## Extra practice
#
# ## 额外练习
#
# Ask the chatbot for help understanding how the `load_dotenv` code works. Ask for step-by-step instructions on how you can create and setup a `.env` file on your own computer.
#
#
# 向聊天机器人寻求帮助以了解“load_dotenv”代码的工作原理。询问有关如何在自己的计算机上创建和设置“.env”文件的分步说明。
