# %% [markdown]
# # L9: Building LLM prompts with variables
#
#
# # L9：使用变量构建 LLM 提示

# %% [markdown]
# In the next cell, you will import the function `print_llm_response` that uses an LLM with an instruction that you provide as a string and displays the result.
#
#
# 在下一个单元中，您将导入函数“print_llm_response”，该函数使用 LLM 以及您以字符串形式提供的指令并显示结果。

# %%
# 添加上层目录或模块目录到路径
import sys
import os
sys.path.append('../')

import importlib
import helper_functions

importlib.reload(helper_functions)

from helper_functions import print_llm_response

# %% [markdown]
# Basically, you can use that function as if you were asking a chatbot. You just need to provide your instructions as a string. For instance, you can ask "What is the capital of France?" using the following code:
#
#
# 基本上，您可以像询问聊天机器人一样使用该功能。您只需以字符串形式提供说明即可。例如，您可以问“法国的首都是哪里？”使用以下代码：

# %%
print_llm_response("What is the capital of France?")
# Out:
# Paris

# %% [markdown]
# Let's ask the LLM for the lifestyle description for Otto Matic, whose name is stored in `name`, if he were a `dog_age` years old dog.
#
#
# 让我们向法学硕士询问 Otto Matic 的生活方式描述，如果他是一只“dog_age”岁的狗，他的名字存储在“name”中。

# %%
name = "Otto Matic"
dog_age = 21/7

# %%
print_llm_response(f"""If {name} were a dog, he would be {dog_age} years old.
Describe what life stage that would be for a dog and what that might 
entail in terms of energy level, interests, and behavior.请用中文回答""")
# Out:
# 3.0岁（即3岁）的狗已完全成年，处于**壮年期（Prime Adulthood）**，相当于人类约20–30岁。
#
# - **能量水平**：精力充沛但趋于稳定，不再像幼犬般亢奋失控，也未进入中老年期的明显衰退；能持续活动1–2小时，恢复快，耐力好。
# - **兴趣与行为**：
#   - 对训练、任务（如敏捷、嗅闻、服从）保持高度兴趣，学习能力强，专注力佳；
#   - 社交成熟，通常能理性应对新环境/陌生人/其他狗，较少出现幼犬的试探性攻击或老年犬的回避；
#   - 有明确的个性和习惯，可能表现出保护欲、游戏欲或工作欲（依品种而异）；
#   - 若缺乏精神/身体刺激，可能出现无聊引发的破坏行为（如啃咬、吠叫），但非因焦虑或叛逆，而是需求未被满足。
#
# 简言之：**稳中有劲，聪慧可靠，正值“黄金工作犬”状态——就像 Otto Matic 那样精准、活跃又靠谱。** 🐕⚙️

# %% [markdown]
# <b>You just used AI with your own variables!</b> You used an LLM with instructions that included variables you defined in this notebook.
#
# <b>您刚刚将 AI 与您自己的变量一起使用！</b>您使用了 LLM，其中包含您在本笔记本中定义的变量的说明。
#
# <b>Congratulations 🎉🎉🎉</b>
#
#
# <b>恭喜🎉🎉🎉</b>

# %% [markdown]
# ## Variable names restrictions
#
#
# ## 变量名称限制

# %% [markdown]
# The following variable names also have some problems. Try to fix them yourself or use the help from the chatbot.
#
#
# 下面的变量名也有一些问题。尝试自己修复它们或使用聊天机器人的帮助。

# %%
driver = "unicorn"
driver_vehicle = "colorful, asymmetric dinosaur car"
favorite_planet = "Pluto"

# %% [markdown]
# Now, update the next cell with any changes you made in the previous cell.
#
#
# 现在，使用您在上一个单元格中所做的任何更改来更新下一个单元格。

# %%
print_llm_response(f"""Write me a 300 word children's story about a {driver} racing
a {driver_vehicle} for the {favorite_planet} champion cup.""")
# Out:
# **The Pluto Champion Cup Race**
#
# On the glittering ice plains of Pluto, where stars winked like fairy lights, the annual Pluto Champion Cup was about to begin! All racers lined up: a sleek comet-sled, a bouncing asteroid-bike—and Zippy, a unicorn with silver hooves that *pinged* like tiny bells and a mane that swirled with soft rainbows.
#
# But Zippy’s biggest rival? **Dino-Dash**—a wildly colorful dinosaur-shaped car! Its head was lime-green, its tail bright orange, one wheel sparkled blue, the other polka-dotted purple. It had three mismatched headlights (a star, a smiley face, and a tiny rocket), and it *honked* in cheerful, off-key trumpets.
#
# “Ready… set… *glow!*” cried Judge Nebula, waving a wand that made the finish line shimmer violet.
#
# *ZING!* Zippy shot forward, hooves kicking up frost-diamonds. Dino-Dash *vroomed*, wobbling slightly—but zooming fast! They raced past frozen geysers (that puffed cotton-candy steam), over bridges of singing ice, and around the Great Crater Loop—where Zippy leapt gracefully, while Dino-Dash bounced *boing-boing-boing!* on its springy tail.
#
# Halfway through, Zippy slipped on a patch of slippery stardust! She stumbled—her rainbow mane flickering dimly. Dino-Dash slowed. *Honk-honk?* Its friendly smiley-headlight blinked.
#
# “Need help?” rumbled Dino-Dash (in a voice like warm toast and giggles).
#
# Zippy nodded. So Dino-Dash extended its stretchy, rubbery tail—and *twang!*—gently pulled her upright. Then—*zoom!*—they raced *side by side*, Zippy’s magic making the air sparkle, Dino-Dash’s wheels painting streaks of joy across the sky.
#
# At the finish line, they crossed… *together*. The crowd gasped—then cheered louder than a supernova!
#
# Judge Nebula smiled. “The Pluto Champion Cup isn’t just for *one* winner—it’s for the bravest heart *and* the kindest gear!”
#
# So Zippy got a crown of frozen moonbeams. Dino-Dash got a medal shaped like a dancing comet. And they shared the trophy: a spinning, double-layered cup—one side glowing unicorn-silver, the other flashing dino-rainbow.
#
# That night, under Pluto’s twin moons, Zippy and Dino-Dash raced *just for fun*—no cups, no clocks—just friendship, speed, and the joyful *ping-honk-boing* of the best team in the solar system. 🌟🦄🚗💫

# %% [markdown]
# ## Extra practice
#
# ## 额外练习
#
# Try the exercises below to practice the concepts from this lesson. Read the comments in each cell with the instructions for each exercise.
#
# 尝试下面的练习来练习本课程中的概念。阅读每个单元格中的注释以及每个练习的说明。
#
# <b>Feel free to use the chatbot if you need help.</b>
#
#
# <b>如果您需要帮助，请随时使用聊天机器人。</b>

# %%
# Fix this code
favorite_book = "1001 Ways to Wear a Hat"
second_fav_book = "2002 Ways to Wear a Scarf"
print(f"My most favorite book is {favorite_book}, but I also like {second_fav_book}")
# Out:
# My most favorite book is 1001 Ways to Wear a Hat, but I also like 2002 Ways to Wear a Scarf

# %%
# Make variables for your favorite game, movie, and food.
# Then use print_llm_response to ask the LLM to recommend you
# a new song to listen to based on your likes.

print_llm_response(f"""

""")
