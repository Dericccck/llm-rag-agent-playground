# %% [markdown]
# # Lesson 5: Vacation planning using CSV files
#
# In this lesson you'll learn to read in and work with data stored in CSV format. Data of this type looks like a table with rows and columns, and is referred to by programmers as **structured data**.
#
# As always, begin by loading the helper functions you'll use:

# %%
# Imports
import sys
import os
import importlib

parent_dir = os.path.dirname(os.getcwd())
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import helper_functions
importlib.reload(helper_functions)
from helper_functions import get_llm_response, print_llm_response, display_table
from IPython.display import Markdown
import csv

# %% [markdown]
# Note that `import csv` here is new. Don't worry about the details for now, but this line of code will be used later to read in CSV data. You'll learn more about this code in Course 4.

# %% [markdown]
# ## Loading data from a CSV file

# %% [markdown]
# You'll use the file ```itinerary.csv```, which has information about arrival and departure dates for each destination in a trip around the world.
#
# Here is the code to load the file - the first part is the same as you've been using up to this point:

# %%
f = open("itinerary.csv", 'r')

# %% [markdown]
# The next part, where you read the data in from the file, is different because you are now reading in a CSV file:

# %%
csv_reader = csv.DictReader(f)
itinerary = []
for row in csv_reader:
    print(row)
    itinerary.append(row)
# Out:
# {'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}
# {'Arrival': 'July-09', 'Departure': 'July-16', 'City': 'Rio de Janeiro', 'Country': 'Brazil'}
# {'Arrival': 'July-17', 'Departure': 'July-24', 'City': 'Cape Town', 'Country': 'South Africa'}
# {'Arrival': 'July-25', 'Departure': 'August-01', 'City': 'Istanbul', 'Country': 'Turkey'}
# {'Arrival': 'August-02', 'Departure': 'August-09', 'City': 'Paris', 'Country': 'France'}
# {'Arrival': 'August-10', 'Departure': 'August-17', 'City': 'Tokyo', 'Country': 'Japan'}
# {'Arrival': 'August-18', 'Departure': 'August-25', 'City': 'Sydney', 'Country': 'Australia'}

# %% [markdown]
# Now close the file:

# %%
f.close()

# %% [markdown]
# You can print the itinerary to view it's content and use the `type` function to check the datatype:

# %%
print(itinerary)
# Out:
# [{'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}, {'Arrival': 'July-09', 'Departure': 'July-16', 'City': 'Rio de Janeiro', 'Country': 'Brazil'}, {'Arrival': 'July-17', 'Departure': 'July-24', 'City': 'Cape Town', 'Country': 'South Africa'}, {'Arrival': 'July-25', 'Departure': 'August-01', 'City': 'Istanbul', 'Country': 'Turkey'}, {'Arrival': 'August-02', 'Departure': 'August-09', 'City': 'Paris', 'Country': 'France'}, {'Arrival': 'August-10', 'Departure': 'August-17', 'City': 'Tokyo', 'Country': 'Japan'}, {'Arrival': 'August-18', 'Departure': 'August-25', 'City': 'Sydney', 'Country': 'Australia'}]

# %%
type(itinerary)
# Out:
# list

# %% [markdown]
# Now take a look at the first item
# * Remember the first item in a list has index 0

# %%
# Print item 0 
print(itinerary[0])
# Out:
# {'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}

# %% [markdown]
# This is a dictionary. You can access a particular value by passing in the key - let's look at the `Country` value in the first row of the itinerary:

# %%
print(itinerary[0]["Country"])
# Out:
# USA

# %% [markdown]
# ## Try for yourself!
#
# Pause the video and explore other rows in the itinerary list, or individual items in any destination. Modify the code below to explore this world tour!

# %%
print(itinerary[0])
print(itinerary[0]["Country"])
# Out:
# {'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}
# USA

# %% [markdown]
# <p style="background-color:#F5C780; padding:15px"> 🤖 <b>Use the Chatbot</b>:
#     <br><br>
#     Explain this code line by line:
#     <br><br>f = open("itinerary.csv", 'r')
#     <br>csv_reader = csv.DictReader(f)
#     <br>itinerary = []
#     <br>for row in csv_reader:
#     <br>itinerary.append(row)
#     <br><br>f.close()
# </p>

# %% [markdown]
# ## Structured Data

# %% [markdown]
# Let's visualize this itinerary in a more readable way.
#
# * Use the ```display_table``` helper function:

# %%
display_table(itinerary)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Arrival</th>
#       <th>Departure</th>
#       <th>City</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>July-01</td>
#       <td>July-08</td>
#       <td>New York</td>
#       <td>USA</td>
#     </tr>
#     <tr>
#       <td>July-09</td>
#       <td>July-16</td>
#       <td>Rio de Janeiro</td>
#       <td>Brazil</td>
#     </tr>
#     <tr>
#       <td>July-17</td>
#       <td>July-24</td>
#       <td>Cape Town</td>
#       <td>South Africa</td>
#     </tr>
#     <tr>
#       <td>July-25</td>
#       <td>August-01</td>
#       <td>Istanbul</td>
#       <td>Turkey</td>
#     </tr>
#     <tr>
#       <td>August-02</td>
#       <td>August-09</td>
#       <td>Paris</td>
#       <td>France</td>
#     </tr>
#     <tr>
#       <td>August-10</td>
#       <td>August-17</td>
#       <td>Tokyo</td>
#       <td>Japan</td>
#     </tr>
#     <tr>
#       <td>August-18</td>
#       <td>August-25</td>
#       <td>Sydney</td>
#       <td>Australia</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Next, write code to filter the table based on some criterion - in this case if the country is Japan - and then add the information for that stop to a new list called `filtered_data`:

# %%
# Create an empty list to store the filtered data
filtered_data = []

# Filter by country
for trip_stop in itinerary:
    # For example: get the destinations located in "Japan"
    if trip_stop["Country"] == "Japan":
        filtered_data.append(trip_stop)

# %%
display_table(filtered_data)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Arrival</th>
#       <th>Departure</th>
#       <th>City</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>August-10</td>
#       <td>August-17</td>
#       <td>Tokyo</td>
#       <td>Japan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note that the `filtered_data` variable only contains one row.

# %% [markdown]
# ## Using AI to suggest trip activities

# %% [markdown]
# Retrieve the first destination and then ask an LLM for suggestions of activities to do in that location during the dates of the visit:

# %%
# Select the first destination from the itinerary list (Hint: index=0)
trip_stop = itinerary[0]
print(trip_stop)
# Out:
# {'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}

# %% [markdown]
# Create variables to store all the individual items from ```trip_stop```:

# %%
city = trip_stop["City"]
country = trip_stop["Country"]
arrival = trip_stop["Arrival"]
departure = trip_stop["Departure"]

# %% [markdown]
# Write a prompt to get activity suggestions for your trip destination:

# %%
prompt = f"""I will visit {city}, {country}, from {arrival} to {departure}. 
Please create a detailed daily itinerary."""

print(prompt)
# Out:
# I will visit New York, USA, from July-01 to July-08.
# Please create a detailed daily itinerary.

# %% [markdown]
# Use Markdown to display the LLM response nicely in the Jupyter notebook:

# %%
# Store the LLM response
response = get_llm_response(prompt)

# Print in Markdown format
display(Markdown(response))
# Out:
# Here's a **detailed daily itinerary** for your 7-day trip to **New York City, USA (July 1–8)**. This plan balances iconic landmarks, cultural experiences, food, and some hidden gems.
#
# ---
#
# ### **Day 1 – July 1: Arrival & Exploring Manhattan**
# **Theme: First Impressions**
# - **Morning:**
#   - Arrive at JFK/LGA/EWR and check into your hotel (recommended areas: Midtown, Times Square, or Lower Manhattan).
#   - Light walk around your neighborhood.
# - **Afternoon:**
#   - **Central Park** (iconic spots: Bethesda Terrace, Strawberry Fields, Bow Bridge).
#   - Grab lunch at **Tavern on the Green** or a casual bite at **Zabar’s** (Upper West Side).
# - **Evening:**
#   - Walk through **Times Square** and **Broadway** (evening lights).
#   - Optional: See a **Broadway show** (book tickets in advance).
#
# ---
#
# ### **Day 2 – July 2: Iconic NYC**
# **Theme: Must-See Landmarks**
# - **Morning:**
#   - **Statue of Liberty & Ellis Island** (book ferry tickets in advance).
#     - Option: Go up the pedestal or visit the Immigration Museum.
# - **Afternoon:**
#   - **Battery Park**, **9/11 Memorial & Museum**, **One World Observatory**.
# - **Evening:**
#   - Dinner in **Financial District** (e.g., **The Odeon**).
#   - Walk the **High Line** at sunset.
#   - Drinks at **The Standard High Line** rooftop.
#
# ---
#
# ### **Day 3 – July 3: Culture & Museums**
# **Theme: Art & Culture Day**
# - **Morning:**
#   - **The Metropolitan Museum of Art** (spend 2–3 hours).
#   - Walk around **Central Park’s east side** afterward.
# - **Afternoon:**
#   - Lunch at **Shake Shack** in **Central Park**.
#   - Visit **Guggenheim Museum** or **MoMA** (choose one).
# - **Evening:**
#   - Stroll through **Fifth Avenue** for shopping.
#   - Dinner in **Midtown** (e.g., **Carmine’s** for Italian).
#
# ---
#
# ### **Day 4 – July 4: Celebrate Independence Day**
# **Theme: Fireworks & Festivities**
# - **All Day:**
#   - Enjoy the **4th of July Parade** in your area or local events.
#   - NYC hosts a **fireworks show** over the East River (best views from **Brooklyn Bridge Park**, **Herald Cove**, or **Liberty Island**).
# - **Optional:**
#   - Picnic in **Central Park** or attend a public viewing event.
# - **Evening:**
#   - Watch the **Macy’s 4th of July Fireworks** (approx. 9:45 PM).
#   - Dinner at a rooftop with skyline views (e.g., **230 Fifth**).
#
# ---
#
# ### **Day 5 – July 5: Brooklyn & Queens**
# **Theme: Borough Exploration**
# - **Morning:**
#   - Take the **East River Ferry or subway** to **Williamsburg, Brooklyn**.
#   - Walk **Brooklyn Bridge** (pedestrian path from Manhattan).
#   - Coffee at **Devoción**, explore **McCarren Park**.
# - **Afternoon:**
#   - Lunch at **Lilia** or **Peter Luger Steakhouse**.
#   - Head to **Queens** (e.g., Jackson Heights) for diverse food tour:
#     - Try **Korean BBQ**, **Peruvian**, **Indian**, or **Latin American** cuisine.
# - **Evening:**
#   - Return to Manhattan or stay in Brooklyn for a trendy dinner.
#   - Optional: Comedy club or live music in Brooklyn.
#
# ---
#
# ### **Day 6 – July 6: Nature & Hidden Gems**
# **Theme: Offbeat NYC**
# - **Morning:**
#   - Visit **The Cloisters** (Medieval branch of the Met, Upper Manhattan).
#   - Walk through **Fort Tryon Park**.
# - **Afternoon:**
#   - Lunch at **La Marina de San Basilio** (waterfront in Hudson River Park).
#   - Explore **Greenwich Village**, **Washington Square Park**, and **NYU Campus**.
# - **Evening:**
#   - Dinner in **SoHo** or **West Village**.
#   - Cocktail at **Employees Only** or **Death & Co**.
#
# ---
#
# ### **Day 7 – July 7: Shopping & Departure Prep**
# **Theme: Last-Minute Fun**
# - **Morning:**
#   - Shopping:
#     - **Herald Square (Macy’s Herald Square)**,
#     - **Herald Square to Flatiron District** (shopping + architecture).
#     - **Herald Square to Times Square** via **Madison Avenue**.
# - **Afternoon:**
#   - Lunch at **Eileen’s Special Cheesecake** (Lower East Side).
#   - Optional: **The Vessel**, **Hudson Yards**, or **Whitney Museum**.
# - **Evening:**
#   - Farewell dinner at **Gramercy Tavern** or **ABC Kitchen**.
#   - Pack and rest for departure.
#
# ---
#
# ### **Day 8 – July 8: Departure**
# - Check out of your hotel.
# - Depending on flight time:
#   - Grab a coffee and bagel at **Russ & Daughters** or **Ess-a-Bagel**.
#   - Visit a last-minute souvenir spot (e.g., **Chelsea Market** if time allows).
# - Head to the airport.
#
# ---
#
# ### Tips:
# - **Transportation**: Use the **MTA Subway** or **Citi Bike** for easy movement.
# - **Tickets**: Book museum and ferry tickets in advance.
# - **Weather**: July is hot and humid—pack light, stay hydrated.
# - **Safety**: Be aware of your surroundings, especially at night.
#
# Let me know if you want this tailored to **interests** (e.g., foodie, art lover, family-friendly).

# %% [markdown]
# ## Extra Practice
#
# In these exercises, you'll create an itinerary for another stop on the trip!
#
# ### Exercise 1
#
# First, create a filtered dataset for Brazil. You'll need to update the `if` statement to select the right country.

# %%
# Create an empty list to store the filtered data
filtered_data = []

# Filter by country
for trip_stop in itinerary:
    # For example: get the destinations located in "Brazil"
    # Complete code on next line:
    if trip_stop["Country"] == "":
        filtered_data.append(trip_stop)

print(filtered_data)

# %% [markdown]
# ### Exercise 2
#
# Next, update the variables to pass in the prompt to the LLM. You'll need to modify the code on the next line to select the first item from `filtered_data` rather than the whole `itinerary`.

# %%
trip_stop = itinerary[0]

city = trip_stop["City"]
country = trip_stop["Country"]
arrival = trip_stop["Arrival"]
departure = trip_stop["Departure"]

print(f" The city is: {city}")
print(f" The country is: {country}")
print(" The arrival date is: {arrival}")
print(" The departure date is: {departure}")

# %% [markdown]
# Now, you can run the prompt to get a new itinerary!

# %%
prompt = f"""I will visit {city}, {country}, from {arrival} to {departure}. 
Please create a detailed daily itinerary."""

print_llm_response(prompt)

# %% [markdown]
# ### Challenge exercise!
#
# Complete the code below so that it will **print out the country of every destination** in the `itinerary.csv` file. Ask the chatbot for help if you need it!

# %%
f = open("itinerary.csv", "r")
csv_reader = csv.DictReader(f)
itinerary = []
for row in csv_reader:
    print(row)
    itinerary.append(row)
f.close()

# Complete the next two lines to print the country:
for trip_stop in :
    print()
