# %% [markdown]
# ## 说明
# 代码演示的功能是 RAG (Retrieval-Augmented Generation，检索增强生成)，即 基于文档的问答系统。
#
# 简短说明
# 该功能的核心目标是：
#
# 检索（Retrieval）： 将一份外部文档（例如您的 OutdoorClothingCatalog_1000.csv 产品目录）加载到 向量数据库 中，以便进行语义搜索。
#
# 增强（Augmented）： 当用户提出问题时，系统会先从向量数据库中检索出与问题最相关的几段文本。
#
# 生成（Generation）： 将用户的 原始问题 和检索到的 相关上下文 一起喂给大型语言模型（LLM），由 LLM 结合上下文来生成精确的答案。
#
# 简而言之，它创建了一个能够精确回答用户关于特定文档（如产品目录）内容的问答系统，从而克服了 LLM 知识的局限性。

# %%
import os
from dotenv import load_dotenv, find_dotenv

# --- 1. 环境准备 (与旧版文件保持一致) ---
# 确保加载环境变量
_ = load_dotenv(find_dotenv()) 


# --- 2. 导入更新 (使用模块化的新包) ---
from langchain_openai import ChatOpenAI  # 导入模型和嵌入
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import CSVLoader    # 导入文档加载器
from langchain_community.vectorstores import DocArrayInMemorySearch # 导入内存向量存储
from langchain_core.prompts import ChatPromptTemplate       # 导入核心 Prompt
from langchain_core.runnables import RunnablePassthrough    # 导入 LCEL 核心组件
from langchain_core.output_parsers import StrOutputParser   # 导入输出解析器
from IPython.display import display, Markdown

# 定义文件和查询
file = 'OutdoorClothingCatalog_1000.csv'
# 翻译：请用 Markdown 格式的表格列出所有具有防晒功能的衬衫，并对每件衬衫进行简要描述。
query = "Please list all your shirts with sun protection in a table in markdown and summarize each one."

# --- 3. 数据加载与嵌入 (取代 VectorstoreIndexCreator) ---

# 3.1. 加载数据
loader = CSVLoader(file_path=file)
docs = loader.load()
# docs[0] 包含了一条产品记录

# 3.2. 初始化嵌入模型
# model_name：指定要加载的模型名称 (例如 BGE-Small)
# model_kwargs：配置模型加载参数，如 device="cpu" 或 "cuda"
embeddings = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-en-v1.5",
    model_kwargs={"device": "cpu"}  # 注意：参数名统一为小写
)

# 3.3. 创建向量数据库 (取代 VectorstoreIndexCreator.from_loaders)
# 直接从 docs 和 embeddings 创建内存向量数据库
db = DocArrayInMemorySearch.from_documents(
    docs, 
    embeddings
)

# 3.4. 获取检索器
retriever = db.as_retriever()
# 检索器是 RAG 链的核心组件之一

# --- 4. RAG 链的 LCEL 实现 (取代 RetrievalQA) ---

# 4.1. 初始化 LLM
llm = ChatOpenAI(
    temperature=0.0, 
    model="qwen-max",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    api_key=os.getenv("DASHSCOPE_API_KEY")
    )

# 4.2. 定义 RAG Prompt 模板
# RAG Prompt 必须接收 {context} 和 {question} 两个变量
RAG_PROMPT_TEMPLATE = """
You are a professional outdoor apparel catalog assistant.
Use the following pieces of retrieved context to answer the question. 
If you cannot find the answer in the context, politely state that you cannot answer based on the provided information.

Context:
{context}

Question: {question}
"""
rag_prompt = ChatPromptTemplate.from_template(RAG_PROMPT_TEMPLATE)

# 4.3. 组织 LCEL RAG 链
# 链的输入必须是 {"question": query_string} 字典格式

def format_docs(docs):
    """
    一个辅助函数，将检索到的文档列表格式化为一个大的字符串，供 LLM 使用。
    """
    texts = []
    for doc in docs:
        content = doc.page_content
        if not isinstance(content, str):
            content = str(content)
        texts.append(content)
    return "\n\n".join(texts)

# LCEL RAG 链的核心结构：
rag_chain = (
    # 步骤 1: 定义 Chain 的输入结构 (字典)
    {
        # 'context' 键的值通过管道连接到 retriever，
        # retriever 接收 'question' 键的值进行检索，并将结果传给 format_docs
        "context": retriever | format_docs, 
        
        # 'question' 键的值直接通过，作为后续 Prompt 的输入
        "question": RunnablePassthrough() 
    }
    # 步骤 2: 将格式化后的字典传入 Prompt
    | rag_prompt
    # 步骤 3: 调用 LLM
    | llm
    # 步骤 4: 将 LLM 的 Message 输出解析为纯字符串
    | StrOutputParser()
)

print("===  RAG Chain 结构图 ===")
# .get_graph().draw_ascii() 作用：可视化 LCEL 链的结构，对于复杂 Chain 调试非常有帮助。
# 结构图将展示：Routing Chain -> RunnableBranch [Physics Path, Math Path, Default Path]
print(rag_chain.get_graph().print_ascii())

# --- 5. 执行调用 ---
print(f"Executing RAG Chain with query: {query}")

# LCEL 链的调用方式：.invoke({})
response = rag_chain.invoke({"question": query})

print("\n--- Final Response ---")
display(Markdown(response))
# Out:
# ===  RAG Chain 结构图 ===
#              +---------------------------------+
#              | Parallel<context,question>Input |
#              +---------------------------------+
#                     ***                ***
#                  ***                      ***
#                **                            ***
# +----------------------+                        **
# | VectorStoreRetriever |                         *
# +----------------------+                         *
#             *                                    *
#             *                                    *
#             *                                    *
#     +-------------+                       +-------------+
#     | format_docs |                       | Passthrough |
#     +-------------+*                      +-------------+
#                     ***                ***
#                        ***          ***
#                           **      **
#             +----------------------------------+
#             | Parallel<context,question>Output |
#             +----------------------------------+
#                               *
#                               *
#                               *
#                     +--------------------+
#                     | ChatPromptTemplate |
#                     +--------------------+
#                               *
#                               *
#                               *
#                         +------------+
#                         | ChatOpenAI |
#                         +------------+
#                               *
#                               *
#                               *
#                      +-----------------+
#                      | StrOutputParser |
#                      +-----------------+
#                               *
#                               *
#                               *
#                   +-----------------------+
#                   | StrOutputParserOutput |
#                   +-----------------------+
# None
# Executing RAG Chain with query: Please list all your shirts with sun protection in a table in markdown and summarize each one.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 111
#     108 print(f"Executing RAG Chain with query: {query}")
#     110 # LCEL 链的调用方式：.invoke({})
# --> 111 response = rag_chain.invoke({"question": query})
#     113 print("\n--- Final Response ---")
#     114 display(Markdown(response))
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\runnables\base.py:3088, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3086 with set_config_context(config) as context:
#    3087     if i == 0:
# -> 3088         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3089     else:
#    3090         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\runnables\base.py:3808, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3803     with get_executor_for_config(config) as executor:
#    3804         futures = [
#    3805             executor.submit(_invoke_step, step, input, config, key)
#    3806             for key, step in steps.items()
#    3807         ]
# -> 3808         output = {
#    3809             key: future.result()
#    3810             for key, future in zip(steps, futures, strict=False)
#    3811         }
#    3812 # finish the root run
#    3813 except BaseException as e:
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\runnables\base.py:3809, in <dictcomp>(.0)
#    3803     with get_executor_for_config(config) as executor:
#    3804         futures = [
#    3805             executor.submit(_invoke_step, step, input, config, key)
#    3806             for key, step in steps.items()
#    3807         ]
#    3808         output = {
# -> 3809             key: future.result()
#    3810             for key, future in zip(steps, futures, strict=False)
#    3811         }
#    3812 # finish the root run
#    3813 except BaseException as e:
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\runnables\base.py:3792, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3786 child_config = patch_config(
#    3787     config,
#    3788     # mark each step as a child run
#    3789     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3790 )
#    3791 with set_config_context(child_config) as context:
# -> 3792     return context.run(
#    3793         step.invoke,
#    3794         input_,
#    3795         child_config,
#    3796     )
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\runnables\base.py:3088, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3086 with set_config_context(config) as context:
#    3087     if i == 0:
# -> 3088         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3089     else:
#    3090         input_ = context.run(step.invoke, input_, config)
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_core\vectorstores\base.py:1033, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1031 kwargs_ = self.search_kwargs | kwargs
#    1032 if self.search_type == "similarity":
# -> 1033     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1034 elif self.search_type == "similarity_score_threshold":
#    1035     docs_and_similarities = (
#    1036         self.vectorstore.similarity_search_with_relevance_scores(
#    1037             query, **kwargs_
#    1038         )
#    1039     )
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_community\vectorstores\docarray\base.py:127, in DocArrayIndex.similarity_search(self, query, k, **kwargs)
#     115 def similarity_search(
#     116     self, query: str, k: int = 4, **kwargs: Any
#     117 ) -> List[Document]:
#     118     """Return docs most similar to query.
#     119
#     120     Args:
#    (...)
#     125         List of Documents most similar to the query.
#     126     """
# --> 127     results = self.similarity_search_with_score(query, k=k, **kwargs)
#     128     return [doc for doc, _ in results]
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_community\vectorstores\docarray\base.py:105, in DocArrayIndex.similarity_search_with_score(self, query, k, **kwargs)
#      91 def similarity_search_with_score(
#      92     self, query: str, k: int = 4, **kwargs: Any
#      93 ) -> List[Tuple[Document, float]]:
#      94     """Return docs most similar to query.
#      95
#      96     Args:
#    (...)
#     103         Lower score represents more similarity.
#     104     """
# --> 105     query_embedding = self.embedding.embed_query(query)
#     106     query_doc = self.doc_cls(embedding=query_embedding)
#     107     docs, scores = self.doc_index.find(query_doc, search_field="embedding", limit=k)
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:172, in HuggingFaceEmbeddings.embed_query(self, text)
#     158 """Compute query embeddings using a HuggingFace transformer model.
#     159
#     160 Args:
#    (...)
#     165
#     166 """
#     167 embed_kwargs = (
#     168     self.query_encode_kwargs
#     169     if len(self.query_encode_kwargs) > 0
#     170     else self.encode_kwargs
#     171 )
# --> 172 return self._embed([text], embed_kwargs)[0]
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:124, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     110 """Embed a text using the HuggingFace transformer model.
#     111
#     112 Args:
#    (...)
#     120
#     121 """
#     122 import sentence_transformers  # type: ignore[import]
# --> 124 texts = [x.replace("\n", " ") for x in texts]
#     125 if self.multi_process:
#     126     pool = self._client.start_multi_process_pool()
#
# File c:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:124, in <listcomp>(.0)
#     110 """Embed a text using the HuggingFace transformer model.
#     111
#     112 Args:
#    (...)
#     120
#     121 """
#     122 import sentence_transformers  # type: ignore[import]
# --> 124 texts = [x.replace("\n", " ") for x in texts]
#     125 if self.multi_process:
#     126     pool = self._client.start_multi_process_pool()
#
# AttributeError: 'dict' object has no attribute 'replace'
