# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

load_dotenv(find_dotenv())

# 创建客户端（指向通义千问 API）
client = OpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),  # 从环境变量读取
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

def get_completion(prompt, model="qwen-max"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %% [markdown]
# **Note**: In June 2023, OpenAI updated gpt-3.5-turbo. The results you see in the notebook may be slightly different than those in the video. Some of the prompts have also been slightly modified to product the desired results.

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 技术规格：```{fact_sheet_chair}```

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# **Product Description:**
#
# Introducing the epitome of mid-century modern elegance, our versatile and stylish office chair is a perfect blend of form and function. Designed to complement any setting, from home offices to corporate boardrooms, this chair is part of a beautiful family of office furniture that includes filing cabinets, desks, bookcases, and meeting tables.
#
# **Customizable Elegance:**
# - **Shell Color & Base Finishes:** Choose from a variety of shell colors and base finishes to match your decor. The chair is available in both plastic back with front upholstery (SWC-100) and full upholstery (SWC-110) options, featuring 10 fabric and 6 leather choices.
# - **Base Finish Options:** Select from stainless steel, matte black, gloss white, or chrome to suit your aesthetic preferences.
# - **Armrests:** Available with or without armrests, and if you choose armrests, they come in an 8-position PU design for ultimate comfort and support.
#
# **Comfort and Durability:**
# - **Adjustable Height:** Equipped with a pneumatic chair adjuster, you can easily raise or lower the seat height to find the perfect position.
# - **Dimensions:** The chair measures 53 cm (20.87”) in width, 51 cm (20.08”) in depth, and 80 cm (31.50”) in height. The seat height is 44 cm (17.32”), and the seat depth is 41 cm (16.14”).
# - **Caster Options:** Choose between soft or hard-floor casters, ensuring smooth movement on any surface.
# - **Seat Foam Densities:** Customize your comfort with two seat foam density options: medium (1.8 lb/ft³) or high (2.8 lb/ft³).
#
# **Quality Construction:**
# - **Base:** The 5-wheel base is made of cast aluminum with a modified nylon PA6/PA66 coating, providing durability and stability.
# - **Materials:** The seat is crafted with HD36 foam, ensuring long-lasting comfort and support.
#
# **Country of Origin:**
# - Proudly made in Italy, this chair embodies the finest craftsmanship and attention to detail.
#
# Whether you're furnishing a home office or a professional workspace, this chair offers the perfect combination of style, comfort, and functionality. Elevate your space with this timeless piece of office furniture.

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 最多使用 50 个字。
#
# 技术规格：```{fact_sheet_chair}```

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your space with this mid-century inspired office chair, featuring customizable shell colors, base finishes, and upholstery options. Perfect for home or business, it offers a 5-wheel base, pneumatic height adjustment, and optional armrests, crafted in Italy.

# %%
len(response.split())

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 该描述面向家具零售商，因此应具有技术性并重点关注产品的构成材料。
#
# 最多使用 50 个字。
#
# 技术规格：```{fact_sheet_chair}```
#
#
# 您的任务是帮助营销团队根据技术情况说明书为零售网站创建产品的描述。
#
# 在描述的末尾，在技术规范中包含每个 7 个字符的产品 ID。
#
# 根据技术规格中提供的信息编写产品描述，并用三重反引号分隔。
#
# 该描述是针对家具零售商的，因此本质上应该是技术性的，并重点关注产品所由来的材料。
#
# 最多使用 50 个单词。
#
# 技术规格： '''{fact_sheet_chair}'''

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this mid-century inspired chair features a cast aluminum base with a modified nylon PA6/PA66 coating and 5-wheel plastic-coated aluminum casters. The seat is made from HD36 foam, available in 10 fabric and 6 leather upholstery options.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted from cast aluminum with a modified nylon PA6/PA66 coating, this mid-century inspired chair features a 10mm thick shell and HD36 foam seat. Available in SWC-100 and SWC-110.

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 描述之后，请添加一个表格，列出产品的尺寸。该表格应包含两列。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 第一列填写尺寸名称。第二列仅填写以英寸为单位的测量值。
#
# 该描述面向家具零售商，因此应具有技术性并重点关注产品的构成材料。
# 将表格标题指定为“产品尺寸”。
#
# 在描述的末尾，包含技术规范中的每个 7 个字符的产品 ID。
#
# 将所有内容格式化为可在网站中使用的 HTML。将描述放在<div>元素。
#
# 技术规格：```{fact_sheet_chair}```

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#   <p>Introducing a stunning piece of mid-century inspired office furniture, designed to elevate both home and business environments. This versatile chair is available in two upholstery styles: SWC-100, featuring a plastic back with front upholstery, and SWC-110, which offers full upholstery in your choice of 10 fabric or 6 leather options. The base of the chair can be customized with a finish of stainless steel, matte black, gloss white, or chrome, ensuring it fits seamlessly into any decor.</p>
#
#   <p>Constructed from high-quality materials, this chair boasts a 5-wheel plastic coated aluminum base, providing stability and ease of movement. The cast aluminum shell, with a thickness of 10 mm, is coated with modified nylon PA6/PA66, enhancing durability and longevity. The seat is made from HD36 foam, available in two density options—medium (1.8 lb/ft³) and high (2.8 lb/ft³)—to cater to individual comfort preferences. Additionally, the chair is equipped with a pneumatic adjustment mechanism, allowing for smooth and effortless height adjustments.</p>
#
#   <p>This chair is also offered with or without armrests, and if chosen, the 8-position PU armrests provide ergonomic support. The caster options include both soft and hard-floor designs, ensuring the chair is suitable for any flooring type. Qualified for contract use, this chair is a perfect addition to any workspace, whether at home or in a professional setting.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <table>
#   <caption>Product Dimensions</caption>
#   <tr>
#     <th>Dimension</th>
#     <th>Measurement (inches)</th>
#   </tr>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
# ```

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#   <p>Introducing a stunning piece of mid-century inspired office furniture, designed to elevate both home and business environments. This versatile chair is available in two upholstery styles: SWC-100, featuring a plastic back with front upholstery, and SWC-110, which offers full upholstery in your choice of 10 fabric or 6 leather options. The base of the chair can be customized with a finish of stainless steel, matte black, gloss white, or chrome, ensuring it fits seamlessly into any decor.</p>
#
#   <p>Constructed from high-quality materials, this chair boasts a 5-wheel plastic coated aluminum base, providing stability and ease of movement. The cast aluminum shell, with a thickness of 10 mm, is coated with modified nylon PA6/PA66, enhancing durability and longevity. The seat is made from HD36 foam, available in two density options—medium (1.8 lb/ft³) and high (2.8 lb/ft³)—to cater to individual comfort preferences. Additionally, the chair is equipped with a pneumatic adjustment mechanism, allowing for smooth and effortless height adjustments.</p>
#
#   <p>This chair is also offered with or without armrests, and if chosen, the 8-position PU armrests provide ergonomic support. The caster options include both soft and hard-floor designs, ensuring the chair is suitable for any flooring type. Qualified for contract use, this chair is a perfect addition to any workspace, whether at home or in a professional setting.</p>
#
#   <p>Product IDs: SWC-100, SWC-110</p>
# </div>
#
# <table>
#   <caption>Product Dimensions</caption>
#   <tr>
#     <th>Dimension</th>
#     <th>Measurement (inches)</th>
#   </tr>
#   <tr>
#     <td>Width</td>
#     <td>20.87</td>
#   </tr>
#   <tr>
#     <td>Depth</td>
#     <td>20.08</td>
#   </tr>
#   <tr>
#     <td>Height</td>
#     <td>31.50</td>
#   </tr>
#   <tr>
#     <td>Seat Height</td>
#     <td>17.32</td>
#   </tr>
#   <tr>
#     <td>Seat Depth</td>
#     <td>16.14</td>
#   </tr>
# </table>
# ```

# %% [markdown]
# ## Try experimenting on your own!
