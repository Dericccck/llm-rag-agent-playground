# %% [markdown]
# # Iterative Prompt Development
# # 迭代快速开发
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
# 在本课程中，您将迭代分析和完善提示，以从产品情况说明书生成营销文案。
#
# ## Setup
# ## 设置

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

load_dotenv(find_dotenv())

# 创建客户端（指向通义千问 API）
client = OpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),  # 从环境变量读取
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

def get_completion(prompt, model="qwen-max"):
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %% [markdown]
# **Note**: In June 2023, OpenAI updated gpt-3.5-turbo. The results you see in the notebook may be slightly different than those in the video. Some of the prompts have also been slightly modified to product the desired results.
# **注**：2023 年 6 月，OpenAI 更新了 gpt-3.5-turbo。您在笔记本中看到的结果可能与视频中的结果略有不同。一些提示也进行了轻微修改，以产生所需的结果。

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet
# ## 从产品情况说明书生成营销产品描述
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 技术规格：```{fact_sheet_chair}```

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Introducing the epitome of mid-century elegance, a chair that seamlessly blends timeless design with modern comfort. This versatile piece is part of an exquisite collection of office furniture, including filing cabinets, desks, bookcases, and meeting tables, all crafted to elevate your workspace or home office.
#
# **Design and Customization:**
# - **Shell Color and Base Finishes:** Choose from a variety of shell colors and base finishes to match your personal style. The chair is available in two upholstery options: plastic back with front upholstery (SWC-100) or full upholstery (SWC-110). You can select from 10 fabric and 6 leather options to create a look that’s uniquely yours.
# - **Base Finish Options:** Stainless steel, matte black, gloss white, or chrome—each finish adds a distinct touch to your space.
# - **Armrests:** Available with or without armrests, and if you choose armrests, they come in 8 adjustable positions, ensuring maximum comfort and support.
#
# ...

# %% [markdown]
# ## Issue 1: The text is too long
# ## 问题1：文字太长
# - Limit the number of words/sentences/characters.
# - 限制单词/句子/字符的数量。
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 最多使用 50 个字。
#
# 技术规格：```{fact_sheet_chair}```

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your space with this mid-century inspired office chair, featuring customizable shell colors, base finishes, and upholstery options. Pneumatic height adjustment, optional armrests, and a choice of casters for any floor type. Perfect for home or business. Dimensions: 53x51x80 cm. Made in Italy.

# %%
len(response.split())
# Out:
# 43

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# ## 问题 2. 文字侧重于错误的细节
# - Ask it to focus on the aspects that are relevant to the intended audience.
# - 要求其重点关注与目标受众相关的方面。
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 该描述面向家具零售商，因此应具有技术性并重点关注产品的构成材料。
#
# 最多使用 50 个字。
#
# 技术规格：```{fact_sheet_chair}```
#
#
# 您的任务是帮助营销团队根据技术情况说明书为零售网站创建产品的描述。
#
# 在描述的末尾，在技术规范中包含每个 7 个字符的产品 ID。
#
# 根据技术规格中提供的信息编写产品描述，并用三重反引号分隔。
#
# 该描述是针对家具零售商的，因此本质上应该是技术性的，并重点关注产品所由来的材料。
#
# 最多使用 50 个单词。
#
# 技术规格： '''{fact_sheet_chair}'''

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted in Italy, this mid-century inspired chair features a robust cast aluminum base with a modified nylon PA6/PA66 coating. Available in SWC-100 (plastic back, front upholstery) or SWC-110 (full upholstery) with 16 material options. Equipped with a 5-wheel plastic-coated aluminum base and pneumatic height adjustment.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Crafted from cast aluminum with a modified nylon PA6/PA66 coating, this chair features an HD36 foam seat. Available in SWC-100 and SWC-110 models, it offers a 5-wheel base and pneumatic height adjustment. Ideal for both home and business settings.

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# ## 问题 3. 描述需要尺寸表
# - Ask it to extract information and organize it in a table.
# - 要求它提取信息并将其组织在表格中。
#
# 下方提示词中文
#
# 您的任务是帮助营销团队根据技术情况说明书为产品零售网站创建描述。
#
# 描述之后，请添加一个表格，列出产品的尺寸。该表格应包含两列。
#
# 根据技术规格中提供的信息（以三个反引号分隔）撰写产品描述。
#
# 第一列填写尺寸名称。第二列仅填写以英寸为单位的测量值。
#
# 该描述面向家具零售商，因此应具有技术性并重点关注产品的构成材料。
# 将表格标题指定为“产品尺寸”。
#
# 在描述的末尾，包含技术规范中的每个 7 个字符的产品 ID。
#
# 将所有内容格式化为可在网站中使用的 HTML。将描述放在<div>元素。
#
# 技术规格：```{fact_sheet_chair}```

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# ```html
# <div>
#   <p>Introducing a sophisticated and versatile addition to our mid-century inspired office furniture collection. This chair, available in two models (SWC-100 and SWC-110), is designed to complement any workspace, whether at home or in a business setting, and is also suitable for contract use. The chair can be customized with several shell color and base finish options, including stainless steel, matte black, gloss white, or chrome, allowing it to fit seamlessly into any decor.</p>
#
# ...

# %% [markdown]
# ## Load Python libraries to view HTML
# ## 加载Python库以查看HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# ```html
# <div>
#   <p>Introducing a sophisticated and versatile addition to our mid-century inspired office furniture collection. This chair, available in two models (SWC-100 and SWC-110), is designed to complement any workspace, whether at home or in a business setting, and is also suitable for contract use. The chair can be customized with several shell color and base finish options, including stainless steel, matte black, gloss white, or chrome, allowing it to fit seamlessly into any decor.</p>
#
# ...

# %% [markdown]
# ## Try experimenting on your own!
# ## 尝试自己尝试一下！
