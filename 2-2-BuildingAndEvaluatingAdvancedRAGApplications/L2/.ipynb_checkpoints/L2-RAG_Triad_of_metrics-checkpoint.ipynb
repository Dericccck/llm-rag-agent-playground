# %% [markdown]
# # Lesson 2: RAG Triad of metrics

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import importlib
import utils
importlib.reload(utils)

import os
import openai

# %%
from trulens_eval import Tru

# 创建 Tru 类的实例对象
tru = Tru()
# 重置数据库，删除所有之前存储的评估数据
tru.reset_database()
# Out:
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["./eBook-How-to-Build-a-Career-in-AI.pdf"]
).load_data()

# %%
from llama_index.core import Document

document = Document(text="\n\n".\
                    join([doc.text for doc in documents]))

# %%
from utils import build_sentence_window_index

from llama_index.core import Settings
from llama_index.llms.openai_like import OpenAILike

# OpenAILike: LlamaIndex 中用于连接与 OpenAI API 兼容的服务的类
# 这里用于连接阿里云的通义千问 (DashScope) 服务
#    配置了 API Key、基础 URL (api_base) 和模型 (qwen-max)。
#    设置了较低的 temperature=0.1，以获得更确定性的回答。
#    设置了较大的 context_window=128000。
llm = OpenAILike(
    api_key=utils.get_dashscope_api_key(),
    api_base="https://dashscope.aliyuncs.com/compatible-mode/v1",
    model="qwen-max",
    temperature=0.1,
    context_window=128000,
    is_chat_model=True,
    is_function_calling_model=False,
)

# 使用自定义函数构建或加载 Sentence Window Index（句子窗口索引）。
# 这是 LlamaIndex 中一种优化检索的方法：检索小块（句子），但提供大块上下文（窗口）给 LLM。
sentence_index = build_sentence_window_index(
    document,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="sentence_index"
)
# Out:
# Loading llama_index.core.storage.kvstore.simple_kvstore from sentence_index\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from sentence_index\index_store.json.

# %%
from utils import get_sentence_window_query_engine

# 获取 Sentence Window 查询引擎。该引擎会自动执行 "检索句子+回填窗口上下文" 的逻辑。
sentence_window_engine = \
get_sentence_window_query_engine(sentence_index)

# %%
output = sentence_window_engine.query(
    "How do you create your AI portfolio?")
output.response
# Out:
# "To create your AI portfolio, focus on building a series of projects that showcase your skills and their progression over time. Start by selecting projects that align with your career goals and the areas of AI you are most interested in. As you complete each project, document your process, the challenges you faced, and how you overcame them. It's also important to highlight the technologies and methodologies you used. By doing this, you can effectively demonstrate your capabilities and growth in the field of AI, making your portfolio an attractive showcase for potential employers."

# %% [markdown]
# ## Feedback functions

# %%
import nest_asyncio
# ----------------------------------------------------------------------
# 异步环境配置
# ----------------------------------------------------------------------
# nest_asyncio.apply()：用于解决在Jupyter/Colab环境中运行异步代码时，
#                       事件循环可能已经运行的问题。确保TruLens的异步评估能正常工作。
nest_asyncio.apply()

# %%
# from trulens_eval import OpenAI as fOpenAI
# provider = fOpenAI()
from trulens.providers.litellm import LiteLLM
# liteLLM_provider：使用 LiteLLM 封装的提供者，将大模型服务（如 DashScope/Qwen-Max）
#                 接入 TruLens，用于执行评估任务（如相关性判断、事实一致性检查）。
provider = LiteLLM(model_engine="dashscope/qwen-max")

# %% [markdown]
# ### 1. Answer Relevance

# %%
from trulens_eval import Feedback

# ----------------------------------------------------------------------
# TruLens 评估指标定义 (Feedback Functions)
# ----------------------------------------------------------------------
# 回答相关性：衡量的是 Input (问题) 和 Output (回答) 之间的相关性
f_qa_relevance = (
    Feedback(provider.relevance_with_cot_reasons, name="Answer Relevance")
    .on_input()  # 评估的第一个输入是用户问题 (Input)
    .on_output() # 评估的第二个输入是 LLM 的答案 (Output)
)

# %% [markdown]
# ### 2. Context Relevance

# %%
from trulens_eval import TruLlama
# 定义一个数据选择器（selector），用于指定 TruLens 在评估过程中应捕获和记录 RAG 流程中的哪个特定部分作为上下文。
context_selection = TruLlama.select_source_nodes().node.text

# %%
import numpy as np

# --- 第一种 Context Relevance 评估：基础相关性 ---
f_qs_relevance = (
    Feedback(provider.relevance,
             name="Context Relevance")
    .on_input() # 指定第一个输入：用户查询（Question）。
    .on_context(collect_list=True) # 指定第二个输入：检索到的上下文（Source Nodes）。
                                    # collect_list=True 确保将检索到的所有上下文块作为一个列表收集。
    .aggregate(np.mean) # 聚合函数：对所有检索到的上下文块的得分求平均值，作为最终的“Context Relevance”分数。
)

# %%
import numpy as np

# --- 第二种 Context Relevance 评估：带COT理由的相关性 ---
f_qs_relevance = (
    Feedback(
        # 使用带思维链（Chain-of-Thought, COT）理由的问题-源相关性评估器。
        # 相比 qs_relevance，这个评估器会要求LLM先给出推理过程，再给出分数，增加了可解释性。
        provider.relevance_with_cot_reasons,
        name="Context Relevance")
    .on_input() # 指定第一个输入：用户查询（Question）
    .on_context(collect_list=True) # 指定第二个输入：检索到的上下文（Source Nodes），以列表形式收集。
    .aggregate(np.mean) # 聚合函数：对所有上下文块的COT相关性得分求平均值。
)

# %% [markdown]
# ### 3. Groundedness

# %%
f_groundedness = (
    Feedback(
        # 使用 provider（通常是一个LLM）提供的、带有思维链（COT）推理的事实基础性评估方法。
        # 这个函数会判断答案中的每个陈述句是否在上下文中被支持。
        provider.groundedness_measure_with_cot_reasons,
        name="Groundedness"
    )
    .on_context(collect_list=True)
    .on_output()
    .aggregate(np.mean)
)

# %% [markdown]
# ## Evaluation of the RAG application

# %%
from trulens_eval import TruLlama
from trulens_eval import FeedbackMode

tru_recorder = TruLlama(
    sentence_window_engine,
    app_id="App_1",
    feedbacks=[
        f_qa_relevance,
        f_qs_relevance,
        f_groundedness
    ]
)
# Out:
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.embeddings.multi_modal_base.MultiModalEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.base.embeddings.base.BaseEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'object'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'llama_index.core.callbacks.base_handler.BaseCallbackHandler'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'object'>
# instrumenting <class 'tuple'> for base <class 'tuple'>
# instrumenting <class 'tuple'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.types.BasePydanticVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.base.BaseIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'object'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'llama_index.core.graph_stores.types.GraphStore'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Protocol'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'llama_index.core.node_parser.interface.NodeParser'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence_window.SentenceWindowNodeParser'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.keyval_docstore.KVDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.types.BaseDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'llama_index.core.data_structs.data_structs.IndexStruct'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.docstore.types.RefDocInfo'> for base <class 'llama_index.core.storage.docstore.types.RefDocInfo'>
# instrumenting <class 'llama_index.core.storage.docstore.types.RefDocInfo'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.storage.docstore.types.RefDocInfo'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.storage.docstore.types.RefDocInfo'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.storage_context.StorageContext'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.base.base_retriever.BaseRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'object'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai_like.base.OpenAILike'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai.base.OpenAI'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.function_calling.FunctionCallingLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.llm.LLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.base.llms.base.BaseLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'object'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'llama_index.core.base.llms.types.LLMMetadata'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.indices.prompt_helper.PromptHelper'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'object'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.refine.Refine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.base.BaseSynthesizer'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.base.base_query_engine.BaseQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.postprocessor.types.BaseNodePostprocessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'object'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.types.BaseNodePostprocessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'object'>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=e47e2538-7596-42d0-8af3-d949bdabb251, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=2d74b2b5-30f3-4d74-b54a-28b97c007ab8, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=47100b1f-146a-44a4-a40f-0fa5063569a9, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=5a7bbeec-f4f2-40e6-afcc-f13814e87d69, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=bd6bcf9a-9a7c-453c-b896-c94f53cf5c94, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=11de0c73-6fc0-47ce-a9b9-d12fbbdc88c0, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=12f473e2-f2a9-4f3b-9e3d-1393436bdc75, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# ...
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=2a33e41f-179d-49a3-86c4-956f3e34403e, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=41ffebd5-0d82-46cb-91fb-fe74feddc20c, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=dbea6d0a-ce21-42af-bb0b-850494dcd496, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# WARNI [trulens.feedback.computer] feedback_name=Context Relevance, record=ed8ca8a1-679e-4726-9e41-9f288aeb81b5, span_group=None had an error during computation:
# LLMProvider.relevance_with_cot_reasons() got an unexpected keyword argument 'args'
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion

# %%
eval_questions = []
with open('eval_questions.txt', 'r') as file:
    for line in file:
        # Remove newline character and convert to integer
        item = line.strip()
        eval_questions.append(item)

# %%
eval_questions
# Out:
# ['What are the keys to building a career in AI?',
#  'How can teamwork contribute to success in AI?',
#  'What is the importance of networking in AI?',
#  'What are some good habits to develop for a successful career?',
#  'How can altruism be beneficial in building a career?',
#  'What is imposter syndrome and how does it relate to AI?',
#  'Who are some accomplished individuals who have experienced imposter syndrome?',
#  'What is the first step to becoming good at AI?',
#  'What are some common challenges in AI?',
#  'Is it normal to find parts of AI challenging?']

# %%
eval_questions.append("How can I be successful in AI?")

# %%
eval_questions
# Out:
# ['What are the keys to building a career in AI?',
#  'How can teamwork contribute to success in AI?',
#  'What is the importance of networking in AI?',
#  'What are some good habits to develop for a successful career?',
#  'How can altruism be beneficial in building a career?',
#  'What is imposter syndrome and how does it relate to AI?',
#  'Who are some accomplished individuals who have experienced imposter syndrome?',
#  'What is the first step to becoming good at AI?',
#  'What are some common challenges in AI?',
#  'Is it normal to find parts of AI challenging?',
#  'How can I be successful in AI?']

# %%
for question in eval_questions:
    with tru_recorder as recording:
        sentence_window_engine.query(question)

# %%
records, feedback = tru.get_records_and_feedback(app_ids=[])
records.head()
# Out:
#                                       app_id app_name app_version  \
# 0  app_hash_9a8bbe93b76fc0a0eca1a6fc7bd3027e    App_1        base
# 1  app_hash_9a8bbe93b76fc0a0eca1a6fc7bd3027e    App_1        base
# 2  app_hash_9a8bbe93b76fc0a0eca1a6fc7bd3027e    App_1        base
# 3  app_hash_9a8bbe93b76fc0a0eca1a6fc7bd3027e    App_1        base
# 4  app_hash_9a8bbe93b76fc0a0eca1a6fc7bd3027e    App_1        base
#
#                                             app_json  type  \
# 0  {'app_name': 'App_1', 'app_version': 'base', '...  SPAN
# 1  {'app_name': 'App_1', 'app_version': 'base', '...  SPAN
# 2  {'app_name': 'App_1', 'app_version': 'base', '...  SPAN
# 3  {'app_name': 'App_1', 'app_version': 'base', '...  SPAN
# 4  {'app_name': 'App_1', 'app_version': 'base', '...  SPAN
#
#                               record_id input_id  \
# 0  e47e2538-7596-42d0-8af3-d949bdabb251
# 1  47100b1f-146a-44a4-a40f-0fa5063569a9
# 2  5a7bbeec-f4f2-40e6-afcc-f13814e87d69
# 3  bd6bcf9a-9a7c-453c-b896-c94f53cf5c94
# 4  2d74b2b5-30f3-4d74-b54a-28b97c007ab8
#
#                                                input  \
# 0      What are the keys to building a career in AI?
# 1      How can teamwork contribute to success in AI?
# 2        What is the importance of networking in AI?
# 3  What are some good habits to develop for a suc...
# 4  How can altruism be beneficial in building a c...
#
#                                               output tags  ...  \
# 0  To build a career in AI, it's important to foc...       ...
# 1  Teamwork can significantly contribute to succe...       ...
# 2  Networking in AI is crucial for several reason...       ...
# 3  For a successful career, it's beneficial to de...       ...
# 4  Altruism, or the practice of selfless concern ...       ...
#
#   Answer Relevance feedback cost in USD Answer Relevance direction  \
# 0                                   0.0                       True
# 1                                   0.0                       True
# 2                                   0.0                       True
# 3                                   0.0                       True
# 4                                   0.0                       True
#
#   Context Relevance                            Context Relevance_calls  \
# 0              None  [{'span_type': 'eval', 'args': {'args': 'What ...
# 1              None  [{'span_type': 'eval', 'args': {'args': 'How c...
# 2              None  [{'span_type': 'eval', 'args': {'args': 'What ...
# 3              None  [{'span_type': 'eval', 'args': {'args': 'What ...
# 4              None  [{'span_type': 'eval', 'args': {'args': 'How c...
#
#    Context Relevance feedback cost in USD  Context Relevance direction  \
# 0                                     0.0                         True
# 1                                     0.0                         True
# 2                                     0.0                         True
# 3                                     0.0                         True
# 4                                     0.0                         True
#
#    Groundedness                                 Groundedness_calls  \
# 0      0.866667  [{'span_type': 'eval', 'args': {'source': ['In...
# 1      0.833333  [{'span_type': 'eval', 'args': {'source': ['To...
# 2      0.866667  [{'span_type': 'eval', 'args': {'source': ['Co...
# 3      0.888889  [{'span_type': 'eval', 'args': {'source': ['Al...
# 4      0.666667  [{'span_type': 'eval', 'args': {'source': ['Su...
#
#    Groundedness feedback cost in USD  Groundedness direction
# 0                                0.0                    True
# 1                                0.0                    True
# 2                                0.0                    True
# 3                                0.0                    True
# 4                                0.0                    True
#
# [5 rows x 31 columns]

# %%
import pandas as pd

pd.set_option("display.max_colwidth", None)
records[["input", "output"] + feedback]
# Out:
#                                                                             input  \
# 0                                   What are the keys to building a career in AI?
# 1                                   How can teamwork contribute to success in AI?
# 2                                     What is the importance of networking in AI?
# 3                   What are some good habits to develop for a successful career?
# 4                            How can altruism be beneficial in building a career?
# 5                         What is imposter syndrome and how does it relate to AI?
# 6   Who are some accomplished individuals who have experienced imposter syndrome?
# 7                                  What is the first step to becoming good at AI?
# 8                                          What are some common challenges in AI?
# 9                                   Is it normal to find parts of AI challenging?
# 10                                                 How can I be successful in AI?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    output  \
# 0                                                                                                                                                                                                                                        To build a career in AI, it's important to focus on several key areas. First, you need to learn foundational technical skills, which involves prioritizing the topics you study due to the vast amount of information available. Next, working on projects is crucial as it provides practical experience and helps solidify your understanding. Additionally, finding the right job that aligns with your skills and interests is essential. Throughout this journey, being part of a supportive community can make the process easier, whether you're just starting out or have been in the field for years. Collaboration and teamwork are also highlighted as critical for success, especially when tackling large projects.
# 1                                                                                                                                                                                                             Teamwork can significantly contribute to success in AI by allowing for the pooling of diverse skills and perspectives. When working on larger AI projects, having a team means that you can leverage deep technical insights from various members, which is crucial for making informed decisions, such as when to invest in a new technical architecture or when to collect more data of a certain type. This collaborative approach not only helps in steering the project more effectively but also aids in the personal growth of team members, as they learn from each other and develop their leadership skills. Effective teamwork can lead to better problem-solving, more innovative solutions, and ultimately, a more successful project outcome.
# 2                                                                                                                                                                                                 Networking in AI is crucial for several reasons. It helps you connect with professionals who can provide insights into the field, which is particularly important because AI roles and responsibilities can vary significantly between companies. By building a network, you can gain access to valuable advice, learn about different career paths, and understand the specific skills and experiences that are most valued. Additionally, networking can open doors to opportunities that may not be advertised publicly, giving you an edge in your job search. Engaging with others in the AI community, such as through meetups or informational interviews, also allows you to stay updated on the latest trends and developments in this rapidly evolving field.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 For a successful career, it's beneficial to develop good habits in several areas. These include maintaining a healthy diet, regular exercise, and getting enough sleep. Additionally, nurturing personal relationships, being disciplined at work, continuous learning, and practicing self-care are also key. These habits not only help in moving forward in one's career but also in maintaining overall well-being.
# 4                                                                                                                                                                                                                                                               Altruism, or the practice of selfless concern for the well-being of others, can significantly benefit one's career in several ways. By focusing on lifting others as you progress in your own journey, you often create a positive and supportive network around you. This network can provide emotional support, professional advice, and even open up new opportunities that might not have been available otherwise. Additionally, being known for helping others can enhance your reputation, making you a respected and valued member of your professional community. This can lead to better collaboration, stronger relationships, and ultimately, more fulfilling and successful career outcomes.
# 5                                                                                                                                                                                                                                                                                                Imposter syndrome is a psychological pattern where individuals doubt their accomplishments and have a persistent internalized fear of being exposed as a "fraud," despite external evidence of their competence. In the context of AI, newcomers to the field may experience imposter syndrome, feeling that they don't truly belong in the AI community or that their success is undeserved. This can happen even to those who are successful and accomplished, and it's a common experience, affecting a significant number of people across various fields. It's important to recognize these feelings and not let them hinder personal growth and development in AI.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Some accomplished individuals who have experienced imposter syndrome include Sheryl Sandberg, the former COO of Facebook, Michelle Obama, the former U.S. First Lady, Tom Hanks, a well-known actor, and Mike Cannon-Brookes, co-CEO of Atlassian.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      The first step to becoming good at AI, as outlined in the provided information, involves learning technical skills that are essential for a promising AI career. This includes gaining proficiency in coding and understanding the fundamental concepts and tools used in artificial intelligence.
# 8                                                                                                                                                                                                                                                                                                                      Some common challenges in AI include the difficulty in finding a suitable project and estimating its timeline and return on investment, as well as setting realistic expectations. The iterative nature of AI projects can also pose unique challenges for project management, especially when it's unclear how long it will take to reach the desired accuracy. Additionally, even after achieving the target, further adjustments may be needed to handle changes that occur after deployment. Another challenge is working with stakeholders who may not have a deep understanding of AI, which can complicate communication and collaboration.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Yes, it's completely normal to find parts of AI challenging. Many people, even those who have made significant contributions to the field, have faced difficulties and struggled with various aspects of AI, from understanding mathematical concepts to implementing algorithms and tuning models. The important thing is to keep learning and not get discouraged by the challenges.
# 10  To be successful in AI, you can follow a structured approach that includes several key steps. First, focus on your career growth by setting clear goals and understanding the path you need to take. Next, acquire the necessary technical skills that are essential for an AI career, such as programming, machine learning, and data analysis. Consider whether you need to strengthen your math skills, as they can be foundational for many AI concepts.\n\nAdditionally, learn how to scope and manage AI projects effectively, ensuring that they are feasible and aligned with real-world needs. It's also important to select projects that align with your career aspirations and help you build a portfolio that showcases your progression and expertise. Finally, when you're ready to look for a job, use a simple and effective framework to guide your search, helping you to find the right opportunities and present yourself as a strong candidate.
#
#     Answer Relevance Context Relevance  Groundedness
# 0           1.000000              None      0.866667
# 1           1.000000              None      0.833333
# 2           0.333333              None      0.866667
# 3           1.000000              None      0.888889
# 4           1.000000              None      0.666667
# 5           1.000000              None      0.888889
# 6           1.000000              None      1.000000
# 7           1.000000              None      0.666667
# 8           1.000000              None      1.000000
# 9           1.000000              None      1.000000
# 10          1.000000              None      0.761905

# %%
tru.get_leaderboard(app_ids=[])
# Out:
#                       Answer Relevance Context Relevance  Groundedness  \
# app_name app_version
# App_1    base                 0.939394               NaN      0.858153
#
#                        latency  total_cost
# app_name app_version
# App_1    base         6.644578         0.0

# %%
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://localhost:59248 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>
