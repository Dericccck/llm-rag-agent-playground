# %% [markdown]
# # Lesson 1: Advanced RAG Pipeline

# %%
import importlib
import utils
importlib.reload(utils)

import os
import openai

# %%
from llama_index.core import SimpleDirectoryReader

# SimpleDirectoryReader: LlamaIndex 中用于从目录或指定文件加载数据的工具
documents = SimpleDirectoryReader(
    input_files=["./eBook-How-to-Build-a-Career-in-AI.pdf"]
).load_data()

# %%
print(type(documents), "\n")
print(len(documents), "\n")
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
#
# 41
#
# <class 'llama_index.core.schema.Document'>
# Doc ID: 74bc9c5c-3742-4f0b-8fbd-88040565664d
# Text: PAGE 1 Founder, DeepLearning.AI Collected Insights from Andrew
# Ng How to  Build Your Career in AI A Simple Guide

# %% [markdown]
# ## Basic RAG pipeline

# %%
from llama_index.core import Document

# 文档合并: PDF 文件可能会被分割成多个 Document 对象（例如按页）。
# 为了简化处理，代码将所有这些 Document 的文本内容通过换行符 \n\n 连接起来，
# 创建了一个单独的、包含全部文本的 Document 对象
document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings
from llama_index.llms.openai_like import OpenAILike

# OpenAILike: LlamaIndex 中用于连接与 OpenAI API 兼容的服务的类
# 这里用于连接阿里云的通义千问 (DashScope) 服务
#    配置了 API Key、基础 URL (api_base) 和模型 (qwen-max)。
#    设置了较低的 temperature=0.1，以获得更确定性的回答。
#    设置了较大的 context_window=128000。
llm = OpenAILike(
    api_key=utils.get_dashscope_api_key(),
    api_base="https://dashscope.aliyuncs.com/compatible-mode/v1",
    model="qwen-max",
    temperature=0.1,
    context_window=128000,
    is_chat_model=True,
    is_function_calling_model=False,
)

# Settings: LlamaIndex 的全局配置对象
# 将全局的语言模型设置为配置好的 OpenAILike 实例
Settings.llm = llm
# 将全局的嵌入模型设置为本地加载的 BGE-Small 模型，用于将文本内容转化为向量
Settings.embed_model = "local:BAAI/bge-small-en-v1.5"

# VectorStoreIndex.from_documents: 这是 LlamaIndex 中创建向量索引的核心步骤。
# 它使用全局配置的 embed_model，将前面合并的 document 切分（默认按块）并嵌入成向量，存储在一个向量存储中。
index = VectorStoreIndex.from_documents([document])
# Out:
# C:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# 从构建好的索引创建一个查询引擎 (query_engine)。
# 这个引擎负责接收用户的查询，进行检索（找到最相关的文本块），
# 并将检索到的上下文和查询一起发送给全局配置的 llm 以生成答案
query_engine = index.as_query_engine()

# %%
# 对查询引擎进行一次直接查询测试，打印出模型针对该问题的回答
response = query_engine.query(
    "What are steps to take when finding projects to build your experience?"
)
print(str(response))
# Out:
# When finding projects to build your experience, consider the following steps:
#
# 1. **Start Small**: Don't hesitate to begin with small, simple projects. Even a basic project, like training a neural network to mimic a simple function, can be a valuable learning experience and a stepping stone to more complex projects.
#
# 2. **Join Existing Projects**: If you find someone else with an interesting idea, ask to join their project. This can help you gain experience and learn from others.
#
# 3. **Read and Network**: Spend time reading, taking courses, and talking with domain experts. These activities can inspire new project ideas and provide insights into potential areas of interest.
#
# 4. **Focus on an Application Area**: Consider working on applications where machine learning has not yet been widely applied. This can give you a unique opportunity to do innovative work.
#
# 5. **Develop a Side Project**: Even if you have a full-time job, a side project can be a fun and creative way to explore new ideas and strengthen collaborations.
#
# 6. **Evaluate Project Potential**: When choosing a project, consider whether it will help you grow technically, if you have good teammates or collaborators, and if it can serve as a meaningful stepping stone to larger projects.
#
# 7. **Avoid Analysis Paralysis**: Don’t spend too much time deciding on a project, especially if it’s a small one. It’s better to start and refine your approach as you go.
#
# 8. **Consider Different Approaches**: Depending on the situation, you might choose to either study the market and plan carefully before starting (Ready, Aim, Fire) or jump in quickly and adjust as needed (Ready, Fire, Aim).
#
# By following these steps, you can build a portfolio that shows a progression of skills and experiences, which will be beneficial when looking for a job or advancing in your career.

# %% [markdown]
# ## Evaluation setup using TruLens
# ## 使用 TruLens 进行评估设置

# %%
# 从名为 eval_questions.txt 的文件中读取一系列用于评估 RAG 系统性能的问答（QA）问题，并将它们存储在列表 eval_questions 中
eval_questions = []
with open('eval_questions.txt', 'r') as file:
    for line in file:
        # Remove newline character and convert to integer
        item = line.strip()
        print(item)
        eval_questions.append(item)
# Out:
# What are the keys to building a career in AI?
# How can teamwork contribute to success in AI?
# What is the importance of networking in AI?
# What are some good habits to develop for a successful career?
# How can altruism be beneficial in building a career?
# What is imposter syndrome and how does it relate to AI?
# Who are some accomplished individuals who have experienced imposter syndrome?
# What is the first step to becoming good at AI?
# What are some common challenges in AI?
# Is it normal to find parts of AI challenging?

# %%
# You can try your own question:
new_question = "What is the right AI job for me?"
eval_questions.append(new_question)

# %%
print(eval_questions)
# Out:
# ['What are the keys to building a career in AI?', 'How can teamwork contribute to success in AI?', 'What is the importance of networking in AI?', 'What are some good habits to develop for a successful career?', 'How can altruism be beneficial in building a career?', 'What is imposter syndrome and how does it relate to AI?', 'Who are some accomplished individuals who have experienced imposter syndrome?', 'What is the first step to becoming good at AI?', 'What are some common challenges in AI?', 'Is it normal to find parts of AI challenging?', 'What is the right AI job for me?']

# %%
from trulens_eval import Tru
# 创建 Tru 类的实例对象
tru = Tru()
# 重置数据库，删除所有之前存储的评估数据
tru.reset_database()
# Out:
# 2025-10-17 17:34:23,845 - INFO - Context impl SQLiteImpl.
# 2025-10-17 17:34:23,845 - INFO - Will assume non-transactional DDL.
# 2025-10-17 17:34:23,883 - INFO - ✅ OpenTelemetry exporter set: NoneType
# 2025-10-17 17:34:23,954 - INFO - ✅ Added new TrulensOtelSpanProcessor
# 2025-10-17 17:34:23,993 - INFO - Context impl SQLiteImpl.
# 2025-10-17 17:34:23,993 - INFO - Will assume non-transactional DDL.
# 🦑 Initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `TruSession` to prevent this.
# ✅ experimental Feature.OTEL_TRACING enabled.
# 🔒 experimental Feature.OTEL_TRACING is enabled and cannot be changed.
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]

# %% [markdown]
# For the classroom, we've written some of the code in helper functions inside a utils.py file.
# - You can view the utils.py file in the file directory by clicking on the "Jupyter" logo at the top of the notebook.
# - In later lessons, you'll get to work directly with the code that's currently wrapped inside these helper functions, to give you more options to customize your RAG pipeline.
#
# 对于课堂练习，我们已经将部分代码写在一个名为 utils.py 的辅助函数文件中。
# - 你可以点击笔记本顶部的 “Jupyter” 标志，在文件目录中查看这个 utils.py 文件。
# - 在后续的课程中，你将有机会直接操作目前封装在这些辅助函数中的代码，从而让你在自定义 RAG 流水线时拥有更多选择。

# %%
from utils import get_prebuilt_trulens_recorder

# 创建一个 TruLens 记录器
# query_engine 在执行查询时能自动记录输入（问题）、输出（答案）、检索到的上下文
# 以及各种内置的反馈指标（如相关性、一致性等）
tru_recorder = get_prebuilt_trulens_recorder(query_engine,
                                             app_id="Direct Query Engine")
# Out:
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.embeddings.multi_modal_base.MultiModalEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.base.embeddings.base.BaseEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'object'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'llama_index.core.callbacks.base_handler.BaseCallbackHandler'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.types.BasePydanticVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.base.BaseIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'object'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'llama_index.core.graph_stores.types.GraphStore'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Protocol'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.MetadataAwareTextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.TextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.NodeParser'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.keyval_docstore.KVDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.types.BaseDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'llama_index.core.data_structs.data_structs.IndexStruct'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.storage_context.StorageContext'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.base.base_retriever.BaseRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'object'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai_like.base.OpenAILike'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai.base.OpenAI'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.function_calling.FunctionCallingLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.llm.LLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.base.llms.base.BaseLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'object'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'llama_index.core.base.llms.types.LLMMetadata'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.indices.prompt_helper.PromptHelper'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'object'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.refine.Refine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.base.BaseSynthesizer'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.base.base_query_engine.BaseQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'object'>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# ...
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion

# %%
# 在这个上下文管理器中执行的所有测试问题
with tru_recorder as recording:
    for question in eval_questions:
        response = query_engine.query(question)

# %%
# 从 TruLens 数据库中获取所有评估记录和计算的反馈得分
records, feedback = tru.get_records_and_feedback(app_ids=[])

# %%
# 打印出记录（一个 Pandas DataFrame）的前几行，展示了评估结果（如问题、答案、以及计算出的各种 TruLens 指标得分）
records.head()
# Out:
#                                       app_id        app_name app_version  \
# 0  app_hash_036435501dfb9ca99cbc0c2fdf8b03fa  LlamaIndex_App        base
# 1  app_hash_036435501dfb9ca99cbc0c2fdf8b03fa  LlamaIndex_App        base
# 2  app_hash_036435501dfb9ca99cbc0c2fdf8b03fa  LlamaIndex_App        base
# 3  app_hash_036435501dfb9ca99cbc0c2fdf8b03fa  LlamaIndex_App        base
# 4  app_hash_036435501dfb9ca99cbc0c2fdf8b03fa  LlamaIndex_App        base
#
#                                             app_json  type  \
# 0  {'app_name': 'LlamaIndex_App', 'app_version': ...  SPAN
# 1  {'app_name': 'LlamaIndex_App', 'app_version': ...  SPAN
# 2  {'app_name': 'LlamaIndex_App', 'app_version': ...  SPAN
# 3  {'app_name': 'LlamaIndex_App', 'app_version': ...  SPAN
# 4  {'app_name': 'LlamaIndex_App', 'app_version': ...  SPAN
#
#                               record_id input_id  \
# 0  a3eb3c28-0711-433e-9e17-815d789244e6
# 1  696e2219-2c23-4e6c-abb2-8790afc8a10c
# 2  9e6d10e6-e441-45d4-9cfc-5c98e8b00ec7
# 3  28354e69-5809-4bc0-9369-534a84aa1efc
# 4  11847eab-f396-432b-81ec-c838f0c86ff2
#
#                                                input  \
# 0      What are the keys to building a career in AI?
# 1      How can teamwork contribute to success in AI?
# 2        What is the importance of networking in AI?
# 3  What are some good habits to develop for a suc...
# 4  How can altruism be beneficial in building a c...
#
#                                               output tags  ...  \
# 0  Building a career in AI involves several key a...       ...
# 1  In AI, as with many other fields, teamwork sig...       ...
# 2  Networking in AI is crucial for several reason...       ...
# 3  Developing good habits is essential for a succ...       ...
# 4  Altruism can be beneficial in building a caree...       ...
#
#   Answer Relevance feedback cost in USD Answer Relevance direction  \
# 0                                   0.0                       True
# 1                                   0.0                       True
# 2                                   NaN                        NaN
# 3                                   0.0                       True
# 4                                   0.0                       True
#
#   Context Relevance                            Context Relevance_calls  \
# 0          1.000000  [{'span_type': 'eval', 'args': {'prompt': 'Wha...
# 1          0.333333  [{'span_type': 'eval', 'args': {'prompt': 'How...
# 2               NaN                                                NaN
# 3          0.500000  [{'span_type': 'eval', 'args': {'prompt': 'Wha...
# 4          0.000000  [{'span_type': 'eval', 'args': {'prompt': 'How...
#
#    Context Relevance feedback cost in USD  Context Relevance direction  \
# 0                                     0.0                         True
# 1                                     0.0                         True
# 2                                     NaN                          NaN
# 3                                     0.0                         True
# 4                                     0.0                         True
#
#    Groundedness                                 Groundedness_calls  \
# 0           1.0  [{'span_type': 'eval', 'args': {'source': ['Th...
# 1           NaN  [{'span_type': 'eval', 'args': {'source': ['Su...
# 2           NaN                                                NaN
# 3           NaN  [{'span_type': 'eval', 'args': {'source': ['Th...
# 4           NaN  [{'span_type': 'eval', 'args': {'source': ['Th...
#
#    Groundedness feedback cost in USD  Groundedness direction
# 0                                0.0                    True
# 1                                0.0                    True
# 2                                NaN                     NaN
# 3                                0.0                    True
# 4                                0.0                    True
#
# [5 rows x 31 columns]

# %%
# 启动一个本地的、交互式的 Web 用户界面（Dashboard），
# 用于可视化和探索您的 LLM 应用程序（RAG 引擎）的评估结果和性能数据
tru.run_dashboard()
# Out:
# C:\Users\bangsun\AppData\Local\Temp\ipykernel_19700\1997498841.py:2: DeprecationWarning: Method `run_dashboard` has been renamed or moved to `trulens.dashboard.run.run_dashboard`.
#
#   tru.run_dashboard()
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://localhost:59667 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ## Advanced RAG pipeline

# %% [markdown]
# ### 1. Sentence Window retrieval（句子窗口检索）

# %%
# from llama_index.llms import OpenAI

# llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
from utils import build_sentence_window_index

# 使用自定义函数构建或加载 Sentence Window Index（句子窗口索引）。
# 这是 LlamaIndex 中一种优化检索的方法：检索小块（句子），但提供大块上下文（窗口）给 LLM。
sentence_index = build_sentence_window_index(
    document,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="sentence_index"
)
# Out:
# C:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading llama_index.core.storage.kvstore.simple_kvstore from sentence_index\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from sentence_index\index_store.json.

# %%
from utils import get_sentence_window_query_engine

# 获取 Sentence Window 查询引擎。该引擎会自动执行 "检索句子+回填窗口上下文" 的逻辑。
sentence_window_engine = get_sentence_window_query_engine(sentence_index)

# %%
# 执行一次查询测试
window_response = sentence_window_engine.query(
    "how do I get started on a personal project in AI?"
)
print(str(window_response))
# Out:
# To get started on a personal project in AI, begin by choosing a simple idea that interests you and is within your current skill set. For instance, you could start with a basic machine learning task, like training a model to mimic a simple mathematical function. This initial project doesn't need to be groundbreaking; its primary purpose is to help you learn and gain experience.
#
# Next, ensure you have the necessary tools and resources. Familiarize yourself with essential programming languages and libraries, such as Python and TensorFlow or PyTorch. You can find many tutorials and courses online to help you get up to speed with these technologies.
#
# As you work on your project, focus on understanding the core concepts and techniques involved. This will not only help you complete the project but also build a solid foundation for more complex projects in the future. Additionally, make sure to document your progress and results, as this will be valuable for both your learning and for showcasing your work to others.
#
# Finally, don't hesitate to share your project and seek feedback from peers or mentors. This can provide you with valuable insights and help you refine your skills further.

# %%
# 准备开始 Sentence Window 引擎的批量评估
# 先重置 TruLens 数据库，确保只记录当前策略的评估数据
tru.reset_database()

# 为 Sentence Window 查询引擎创建 TruLens 记录器
tru_recorder_sentence_window = get_prebuilt_trulens_recorder(
    sentence_window_engine,
    app_id = "Sentence Window Query Engine"
)
# Out:
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.embeddings.multi_modal_base.MultiModalEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.base.embeddings.base.BaseEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'object'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'llama_index.core.callbacks.base_handler.BaseCallbackHandler'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.types.BasePydanticVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.base.BaseIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'object'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'llama_index.core.graph_stores.types.GraphStore'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Protocol'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.MetadataAwareTextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.TextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.NodeParser'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.keyval_docstore.KVDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.types.BaseDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'llama_index.core.data_structs.data_structs.IndexStruct'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.storage_context.StorageContext'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.base.base_retriever.BaseRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'object'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai_like.base.OpenAILike'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai.base.OpenAI'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.function_calling.FunctionCallingLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.llm.LLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.base.llms.base.BaseLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'object'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'llama_index.core.base.llms.types.LLMMetadata'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.indices.prompt_helper.PromptHelper'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'object'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.refine.Refine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.base.BaseSynthesizer'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.base.base_query_engine.BaseQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.postprocessor.types.BaseNodePostprocessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.postprocessor.metadata_replacement.MetadataReplacementPostProcessor'> for base <class 'object'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.types.BaseNodePostprocessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'object'>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion

# %%
# 使用 TruLens 记录器对所有评估问题进行批量查询和评估
for question in eval_questions:
    with tru_recorder_sentence_window as recording:
        response = sentence_window_engine.query(question)
        print(question)
        print(str(response))
# Out:
# What are the keys to building a career in AI?
# Building a career in AI involves several key aspects:
#
# 1. **Teamwork**: Success in large projects often comes from working collaboratively with others. Developing strong interpersonal and communication skills is crucial, as the ability to work well with a team, influence, and be open to influence can significantly impact your effectiveness.
#
# 2. **Networking (or Community Building)**: While traditional networking might not appeal to everyone, especially those who are more introverted, building a community around shared interests or within the field of AI can be very beneficial. This approach not only helps in making genuine connections but also in creating a support network that can provide assistance and advice when needed.
#
# 3. **Job Search**: It's important to approach the job search process with the right mindset. Finding a job is just one step in a long career journey. Avoiding adversarial attitudes towards potential employers and focusing on mutual fit and growth opportunities can lead to better outcomes.
#
# 4. **Personal Discipline**: Consistently developing good habits in various aspects of life such as learning, health, and personal relationships can contribute to sustained progress and success over time. These habits help in maintaining a balanced and healthy lifestyle while advancing in your career.
#
# 5. **Altruism**: Aiming to help and lift others as you progress in your own career can lead to better personal and professional outcomes. Focusing on how you can contribute positively to the community and support others can enrich your career experience and create a positive impact.
# How can teamwork contribute to success in AI?
# In AI, as with many other fields, teamwork significantly enhances the chances of success. When working on large and complex projects, collaboration allows for the pooling of diverse skills and perspectives, which can lead to more innovative and robust solutions. Effective teamwork also means that members can support each other, share the workload, and tackle challenges together, making it easier to manage the scope and complexity of AI projects. Additionally, being able to communicate and work well with others is crucial, as it fosters a positive environment where ideas can be freely exchanged, and constructive feedback can improve the project outcomes.
# What is the importance of networking in AI?
# Networking in AI is crucial as it helps in building a strong professional community that can provide support, advice, and opportunities. While traditional networking might feel uncomfortable for some, especially for introverts, the focus can be shifted to building up the communities you are part of. This approach not only makes the process more enjoyable but also naturally leads to meeting more people and making genuine connections. A robust network or community can be invaluable when you need help or guidance in your career.
# What are some good habits to develop for a successful career?
# Developing good habits is crucial for a successful career. Some key habits to cultivate include maintaining a healthy lifestyle through proper eating, regular exercise, and adequate sleep. Additionally, fostering strong personal relationships, dedicating time to continuous learning, and practicing self-care are important. These habits not only help in advancing your career but also in sustaining overall well-being.
# How can altruism be beneficial in building a career?
# Altruism, or the practice of helping others, can be highly beneficial in building a career. By aiming to lift others as you progress in your own journey, you often create a positive environment that fosters mutual support and growth. This approach can lead to better outcomes for yourself, as it helps in building strong, meaningful relationships within your professional network. These connections can provide support, open up new opportunities, and enhance your reputation as someone who is not only skilled but also caring and community-oriented. In essence, by being altruistic, you contribute to a more collaborative and supportive professional ecosystem, which can, in turn, benefit your career.
# What is imposter syndrome and how does it relate to AI?
# Imposter syndrome is a feeling where individuals, despite their success and accomplishments, doubt their own skills and feel like they might be seen as a fraud. In the context of AI, it can affect newcomers who may feel out of place or inadequate in a field that is technically complex and filled with highly capable people. This feeling can arise even among those who have achieved significant milestones in AI, as the field often presents challenging problems and continuous learning opportunities. It's important to recognize that experiencing imposter syndrome is common and not unique to any one person; many successful figures in various fields, including AI, have also felt this way. The key message is that if you're interested in AI, you are welcome and belong in the community, and facing challenges is a natural part of the learning and growth process.
# Who are some accomplished individuals who have experienced imposter syndrome?
# Some accomplished individuals who have experienced imposter syndrome include former Facebook COO Sheryl Sandberg, U.S. first lady Michelle Obama, actor Tom Hanks, and Atlassian co-CEO Mike Cannon-Brookes.
# What is the first step to becoming good at AI?
# The first step to becoming good at AI is learning foundational technical skills. This includes understanding key models such as linear regression, logistic regression, neural networks, decision trees, clustering, and anomaly detection. It's also crucial to grasp the core concepts behind how and why machine learning works, such as bias/variance, cost functions, regularization, optimization algorithms, and error analysis. Additionally, gaining knowledge in deep learning and software development, particularly with Python and libraries like TensorFlow, PyTorch, and scikit-learn, is important.
# What are some common challenges in AI?
# Some common challenges in AI include understanding the underlying mathematics, such as those involved in linear regression or logistic regression, and debugging issues in implementing basic neural networks. Additionally, keeping up with and comprehending the latest research papers can be difficult due to their technical complexity. Tuning hyperparameters for neural networks is another area where even experienced practitioners may face difficulties. These technical hurdles are part of the learning process and are experienced by many, regardless of their level of expertise or success in the field.
# Is it normal to find parts of AI challenging?
# Yes, it's completely normal to find parts of AI challenging. Many people, even those who are accomplished in the field, have faced difficulties and struggled with various aspects of AI at some point. Whether it's understanding the math behind certain models or debugging a neural network, encountering challenges is a common experience and part of the learning process.
# What is the right AI job for me?
# Finding the right AI job for you involves several key considerations. First, focus on roles that align with your technical skills and experience. It's important to have a compelling resume and a portfolio of projects that showcase your abilities and are relevant to the positions you're interested in.
#
# When evaluating potential jobs, pay close attention to the team you'll be working with, as they can significantly influence your work and development. Try to meet and speak with potential teammates if possible, as this can give you a better sense of the work environment and culture.
#
# Additionally, seek advice and support from your professional network. Friends, mentors, and colleagues can offer valuable insights and may even provide referrals or recommendations. Engage in informational interviews to gather more information about different roles and companies, which can help you make a more informed decision.
#
# Finally, approach the job search and interview process with a positive and respectful attitude. Prepare thoroughly for interviews, practice common questions, and follow up appropriately. If you receive an offer, consider it carefully, and if you don't, seek feedback to improve for future opportunities. Remember, the right AI job is one where you can grow, contribute, and feel fulfilled.

# %%
# 显示当前数据库中所有应用的 Leaderboard 概览（目前只有 Sentence Window）
tru.get_leaderboard(app_ids=[])
# Out:
#                             Answer Relevance  Context Relevance  Groundedness  \
# app_name       app_version
# LlamaIndex_App base                 0.969697           0.409091      0.923737
#
#                               latency  total_cost
# app_name       app_version
# LlamaIndex_App base         12.437328         0.0

# %%
# launches on http://localhost:8501/
# # 启动 TruLens Dashboard，可视化查看 Sentence Window 引擎的评估结果
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Dashboard already running at path:   Local URL: http://localhost:55913
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ### 2. Auto-merging retrieval(自动合并检索)

# %%
from utils import build_automerging_index

# 使用自定义函数构建或加载 Automerging Index（自动合并索引）。
# 这是另一种优化检索的方法：检索小块，通过上下文分层结构“向上合并”成更大的块供 LLM 使用。
automerging_index = build_automerging_index(
    documents,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index"
)
# Out:
# C:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading llama_index.core.storage.kvstore.simple_kvstore from merging_index\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from merging_index\index_store.json.

# %%
from utils import get_automerging_query_engine

# 获取 Automerging 查询引擎。
automerging_query_engine = get_automerging_query_engine(
    automerging_index,
)
# Out:
# C:\Users\bangsun\miniconda3\envs\jupterlab\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# 执行一次查询测试
auto_merging_response = automerging_query_engine.query(
    "How do I build a portfolio of AI projects?"
)
print(str(auto_merging_response))
# Out:
# > Merging 1 nodes into parent node.
# > Parent node id: dfc23e71-96a3-473e-be7e-1df66c4329ee.
# > Parent node text: PAGE 21
# Building a Portfolio of
# Projects that Shows
# Skill Progression
# CHAPTER 6
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: fceafe79-6bf4-48c4-be14-cba00db32d7a.
# > Parent node text: PAGE 17
# Finding Projects that
# Complement Your
# Career Goals
# CHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: d8f543a4-a478-46e1-8896-cff9d52ec951.
# > Parent node text: PAGE 14
# Scoping Successful
# AI Projects
# CHAPTER 4
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: abfab401-06bf-4dd1-95de-c93960db9936.
# > Parent node text: PAGE 21
# Building a Portfolio of
# Projects that Shows
# Skill Progression
# CHAPTER 6
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8f569a15-54d8-41dd-8115-4a7b44ed2be8.
# > Parent node text: PAGE 17
# Finding Projects that
# Complement Your
# Career Goals
# CHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 27555b48-eb0a-4cb3-b2d9-c842c9e568b6.
# > Parent node text: PAGE 14
# Scoping Successful
# AI Projects
# CHAPTER 4
# PROJECTS
#
# To build a portfolio of AI projects, start by selecting a range of projects that show your progression from simpler to more complex tasks. This will help demonstrate your growth and learning over time. It's also important to choose projects that are meaningful and can showcase your ability to identify valuable ideas. Consider exploring different industries such as manufacturing, healthcare, climate change, agriculture, ecommerce, or advertising, even if you're not an expert in these areas. By doing so, you can gain diverse experience and highlight your adaptability and problem-solving skills. Additionally, ensure that you can effectively communicate the value and thought process behind your work, as this is crucial for others to understand and appreciate your contributions.

# %%
# 准备开始 Automerging 引擎的批量评估
# 注意：这里再次 reset_database() 会清除 Sentence Window 的记录！
# 在实际对比中，通常只在所有测试完成后再调用一次 Leaderboard/Dashboard，而非清除重来。
# 假设这里重置是为了确保 Automerging 的评估从干净的数据库开始，便于观察其自身的性能。
tru.reset_database()

# 为 Automerging 查询引擎创建 TruLens 记录器
tru_recorder_automerging = get_prebuilt_trulens_recorder(automerging_query_engine,
                                                         app_id="Automerging Query Engine")
# Out:
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.embeddings.multi_modal_base.MultiModalEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.base.embeddings.base.BaseEmbedding'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.embeddings.huggingface.base.HuggingFaceEmbedding'> for base <class 'object'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'llama_index.core.callbacks.base_handler.BaseCallbackHandler'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.vector_stores.types.BasePydanticVectorStore'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.vector_stores.simple.SimpleVectorStoreData'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'llama_index.core.indices.base.BaseIndex'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.base.VectorStoreIndex'> for base <class 'object'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'llama_index.core.graph_stores.types.GraphStore'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Protocol'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'typing.Generic'>
# instrumenting <class 'llama_index.core.graph_stores.simple.SimpleGraphStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.MetadataAwareTextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.TextSplitter'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.node_parser.interface.NodeParser'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.TransformComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.node_parser.text.sentence.SentenceSplitter'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.keyval_docstore.KVDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'llama_index.core.storage.docstore.types.BaseDocumentStore'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore'> for base <class 'object'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'llama_index.core.data_structs.data_structs.IndexStruct'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'dataclasses_json.api.DataClassJsonMixin'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.data_structs.data_structs.IndexDict'> for base <class 'object'>
# instrumenting <class 'llama_index.core.storage.storage_context.StorageContext'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.base.base_retriever.BaseRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever'> for base <class 'object'>
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'llama_index.core.base.base_retriever.BaseRetriever'>
# 	instrumenting retrieve
# 	instrumenting _retrieve
# 	instrumenting _aretrieve
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.retrievers.auto_merging_retriever.AutoMergingRetriever'> for base <class 'object'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'llama_index.core.callbacks.base_handler.BaseCallbackHandler'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.callbacks.base.CallbackManager'> for base <class 'object'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai_like.base.OpenAILike'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.llms.openai.base.OpenAI'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.function_calling.FunctionCallingLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.llms.llm.LLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.base.llms.base.BaseLLM'>
# 	instrumenting chat
# 	instrumenting complete
# 	instrumenting stream_chat
# 	instrumenting stream_complete
# 	instrumenting achat
# 	instrumenting acomplete
# 	instrumenting astream_chat
# 	instrumenting astream_complete
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.llms.openai_like.base.OpenAILike'> for base <class 'object'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'llama_index.core.base.llms.types.LLMMetadata'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.base.llms.types.LLMMetadata'> for base <class 'object'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.indices.prompt_helper.PromptHelper'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.indices.prompt_helper.PromptHelper'> for base <class 'object'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.refine.Refine'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.response_synthesizers.base.BaseSynthesizer'>
# 	instrumenting get_response
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.response_synthesizers.compact_and_refine.CompactAndRefine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'llama_index.core.prompts.base.BasePromptTemplate'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.prompts.base.SelectorPromptTemplate'> for base <class 'object'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.base.base_query_engine.BaseQueryEngine'>
# 	instrumenting query
# 	instrumenting aquery
# 	instrumenting synthesize
# 	instrumenting asynthesize
# 	instrumenting retrieve
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index.core.prompts.mixin.PromptMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'> for base <class 'object'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.postprocessor.types.BaseNodePostprocessor'>
# 	instrumenting _postprocess_nodes
# 	instrumenting postprocess_nodes
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index.core.schema.BaseComponent'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'pydantic.main.BaseModel'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'llama_index_instrumentation.DispatcherSpanMixin'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'abc.ABC'>
# instrumenting <class 'llama_index.core.postprocessor.sbert_rerank.SentenceTransformerRerank'> for base <class 'object'>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# [nltk_data] Error loading punkt_tab: <urlopen error [WinError 10061]
# [nltk_data]     由于目标计算机积极拒绝，无法连接。>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# [nltk_data] Error loading punkt_tab: <urlopen error [WinError 10061]
# [nltk_data]     由于目标计算机积极拒绝，无法连接。>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# [nltk_data] Error loading punkt_tab: <urlopen error [WinError 10061]
# [nltk_data]     由于目标计算机积极拒绝，无法连接。>
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# ...
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion
# litellm-completion-Using model: qwen-max from provider: dashscope dynamic_api_key：sk-115fda5d825f49d59fa6484b57330052, api_base：https://dashscope.aliyuncs.com/compatible-mode/v1
# Using OpenAI provider : ['anyscale', 'groq', 'nvidia_nim', 'cerebras', 'baseten', 'sambanova', 'ai21_chat', 'ai21', 'volcengine', 'codestral', 'deepseek', 'deepinfra', 'perplexity', 'xinference', 'xai', 'together_ai', 'fireworks_ai', 'empower', 'friendliai', 'azure_ai', 'github', 'litellm_proxy', 'hosted_vllm', 'llamafile', 'lm_studio', 'galadriel', 'github_copilot', 'novita', 'meta_llama', 'featherless_ai', 'nscale', 'nebius', 'dashscope', 'moonshot', 'v0', 'morph', 'lambda_ai', 'hyperbolic', 'vercel_ai_gateway', 'aiml']
# Using OpenAI provider-use_base_llm_http_handler : None
# Using OpenAI provider-openai_chat_completions.completion

# %%
# 使用 TruLens 记录器对所有评估问题进行批量查询和评估
for question in eval_questions:
    with tru_recorder_automerging as recording:
        response = automerging_query_engine.query(question)
        print(question)
        print(response)
# Out:
# > Merging 2 nodes into parent node.
# > Parent node id: 8d1b99f1-153a-4e1b-bda4-e61f15eabed9.
# > Parent node text: PAGE 3
# Table of
# Contents
# Introduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 44110bb5-f855-4d1f-8ea6-cf5782460d5e.
# > Parent node text: PAGE 3
# Table of
# Contents
# Introduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to ...
#
# What are the keys to building a career in AI?
# To build a career in AI, it's important to focus on several key areas. First, you should learn foundational technical skills, which are essential for understanding and working with AI technologies. Additionally, gaining practical experience by working on projects can help solidify your knowledge and provide real-world application of your skills. Networking and being part of a community is also crucial, as it can offer support, collaboration opportunities, and insights into the industry. Furthermore, developing strong teamwork and collaboration skills is vital, as success in large projects often comes from working effectively with others.
# How can teamwork contribute to success in AI?
# Teamwork is essential for success in AI because it allows individuals to collaborate, influence, and be influenced by others. Working together on large projects can lead to better outcomes than working individually. Effective teamwork leverages the diverse skills and perspectives of team members, which is particularly important in a multidisciplinary field like AI. Good interpersonal and communication skills are key, as they facilitate the sharing of ideas, problem-solving, and the overall progress of the project.
# > Merging 3 nodes into parent node.
# > Parent node id: 6ed38663-ab9f-415d-82e6-9a5c615b8dab.
# > Parent node text: PAGE 35
# Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more compl...
#
# > Merging 1 nodes into parent node.
# > Parent node id: fe3881f6-4f5d-4dcf-90a3-582dbdad7265.
# > Parent node text: PAGE 35
# Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more compl...
#
# What is the importance of networking in AI?
# Networking in AI is crucial for several reasons. It helps in building a supportive professional community that can provide guidance, advice, and opportunities. While traditional networking might not be appealing to everyone, especially introverts, focusing on community building can be an effective alternative. By contributing to and engaging with communities, you naturally expand your network, which can lead to valuable connections and friendships. These relationships can be instrumental in advancing your career, offering support, and opening doors to new possibilities.
# > Merging 2 nodes into parent node.
# > Parent node id: 1a6bbf5b-7374-4dea-87ea-6ca350e2c90d.
# > Parent node text: PAGE 36
# Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# o...
#
# > Merging 3 nodes into parent node.
# > Parent node id: f29c0f19-c004-4417-8579-ad85f8d9bf07.
# > Parent node text: PAGE 32
# In this chapter, I’d like to
# discuss some fine points
# of finding a job.
# The typical job...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 04d28b26-ee4a-465b-a608-602b11378be3.
# > Parent node text: PAGE 11
# The Best Way to Build
# a New Habit
# One of my favorite books is BJ Fogg’s, Tiny Habits: Th...
#
# > Merging 1 nodes into parent node.
# > Parent node id: a44c3ebc-3665-48bf-bd1d-68266004cc99.
# > Parent node text: PAGE 36
# Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# o...
#
# > Merging 1 nodes into parent node.
# > Parent node id: d35cd3e5-3091-4c4b-8ccc-21615be4c946.
# > Parent node text: PAGE 11
# The Best Way to Build
# a New Habit
# One of my favorite books is BJ Fogg’s, Tiny Habits: Th...
#
# What are some good habits to develop for a successful career?
# Developing good habits in several areas can contribute to a successful career. It's beneficial to focus on maintaining a healthy lifestyle, which includes proper eating, regular exercise, and adequate sleep. Additionally, fostering strong personal relationships and practicing self-care are important. In terms of work, consistent learning and disciplined work habits are key. Starting small and building up, such as committing to a brief daily study session, can help establish a routine that supports continuous growth and development. Helping others along the way can also lead to better outcomes for your own career.
# How can altruism be beneficial in building a career?
# Altruism can be highly beneficial in building a career, as it involves helping others and lifting them up during your own journey. By being supportive and generous, you not only contribute to a positive community but also create a network of individuals who may reciprocate that support. This can lead to better outcomes for yourself, such as new opportunities, collaborations, and a stronger professional network. Additionally, paying it forward by assisting those who are starting out can enhance your reputation and make you a respected figure in your field.
# > Merging 5 nodes into parent node.
# > Parent node id: b3dcb17b-371e-4280-8853-051920ad9c93.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 448f1c76-5403-481e-a6eb-327a8470d2d5.
# > Parent node text: PAGE 37
# Overcoming Imposter
# Syndrome
# CHAPTER 11
#
# > Merging 3 nodes into parent node.
# > Parent node id: e7a6875a-39cb-41f9-9ffa-58b1b798f6ae.
# > Parent node text: PAGE 39
# My three-year-old daughter (who can barely count to 12) regularly tries to teach things t...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0c6bc10d-2fcb-4e77-b51f-4e0906cb80d2.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c86e04e4-38d1-42a9-b2cc-01841afa0752.
# > Parent node text: PAGE 37
# Overcoming Imposter
# Syndrome
# CHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 747d5fcc-7051-435b-a8b4-d89b90c34daf.
# > Parent node text: PAGE 39
# My three-year-old daughter (who can barely count to 12) regularly tries to teach things t...
#
# What is imposter syndrome and how does it relate to AI?
# Imposter syndrome is a common feeling where individuals, despite their achievements and success, doubt their own skills and fear being exposed as a fraud. In the context of AI, it can affect newcomers who might feel they don't truly belong in the community or are not as capable as others. This feeling can arise due to the technical complexity of AI and the presence of many highly skilled individuals in the field. It's important to recognize that even accomplished people in AI have faced similar challenges and doubts, and that experiencing imposter syndrome does not diminish one's potential or value in the AI community.
# > Merging 3 nodes into parent node.
# > Parent node id: b3dcb17b-371e-4280-8853-051920ad9c93.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 448f1c76-5403-481e-a6eb-327a8470d2d5.
# > Parent node text: PAGE 37
# Overcoming Imposter
# Syndrome
# CHAPTER 11
#
# > Merging 3 nodes into parent node.
# > Parent node id: e7a6875a-39cb-41f9-9ffa-58b1b798f6ae.
# > Parent node text: PAGE 39
# My three-year-old daughter (who can barely count to 12) regularly tries to teach things t...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0c6bc10d-2fcb-4e77-b51f-4e0906cb80d2.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c86e04e4-38d1-42a9-b2cc-01841afa0752.
# > Parent node text: PAGE 37
# Overcoming Imposter
# Syndrome
# CHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 747d5fcc-7051-435b-a8b4-d89b90c34daf.
# > Parent node text: PAGE 39
# My three-year-old daughter (who can barely count to 12) regularly tries to teach things t...
#
# Who are some accomplished individuals who have experienced imposter syndrome?
# Some accomplished individuals who have experienced imposter syndrome include former Facebook COO Sheryl Sandberg, U.S. first lady Michelle Obama, actor Tom Hanks, and Atlassian co-CEO Mike Cannon-Brookes.
# What is the first step to becoming good at AI?
# The first step to becoming good at AI is to start learning foundational technical skills. It's important to remember that everyone begins by not being very good, and that's a natural part of the process. As you learn and practice, you'll gradually improve.
# > Merging 4 nodes into parent node.
# > Parent node id: 6d184a62-76cd-4a6d-9f95-6d7d3acae12b.
# > Parent node text: PAGE 15
# One of the most important skills of an AI architect is the ability to identify ideas that...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c7986883-9a29-4140-ab99-f85da15899ba.
# > Parent node text: PAGE 15
# One of the most important skills of an AI architect is the ability to identify ideas that...
#
# What are some common challenges in AI?
# Some common challenges in AI include the difficulty in finding a suitable project and estimating its timeline and return on investment. Additionally, setting expectations can be tough due to the highly iterative nature of AI projects, which often makes it hard to plan for building a system when the time required to achieve the target accuracy is uncertain. These challenges are part of the learning process and are faced by many, even those who have made significant contributions to the field.
# > Merging 3 nodes into parent node.
# > Parent node id: b3dcb17b-371e-4280-8853-051920ad9c93.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0c6bc10d-2fcb-4e77-b51f-4e0906cb80d2.
# > Parent node text: PAGE 38
# Before we dive into the final chapter of this book, I’d like to address the serious matte...
#
# Is it normal to find parts of AI challenging?
# Yes, it's completely normal to find parts of AI challenging. Many people, even those who are accomplished in the field, have faced difficulties and struggled with various aspects of AI. Whether it's understanding the math behind certain concepts or troubleshooting issues with implementations, these challenges are a common part of the learning and growth process. Remember, everyone starts by finding things difficult before they become more proficient.
# > Merging 1 nodes into parent node.
# > Parent node id: 976bee4f-9c7a-48f6-b0f7-3b59ae8cd171.
# > Parent node text: If you’re leaving
# a job, exit gracefully. Give your employer ample notice, give your full effort...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5983ea5d-c501-49e2-8d10-51b620337757.
# > Parent node text: PAGE 31
# Finding the Right
# AI Job for You
# CHAPTER 9
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 221f166b-8869-442c-b073-5d3088e80e73.
# > Parent node text: PAGE 31
# Finding the Right
# AI Job for You
# CHAPTER 9
# JOBS
#
# What is the right AI job for me?
# To find the right AI job for you, it's important to consider several factors. Reflect on your skills, interests, and career goals. Think about the type of work that excites you, whether it's research, development, or application of AI in specific industries. Consider the work environment that suits you best, such as a startup, a large corporation, or an academic setting. Additionally, think about the impact you want to make and the challenges you are willing to take on. Exploring these aspects will help guide you towards a role that aligns with your personal and professional aspirations.

# %%
# 显示当前数据库中所有应用的 Leaderboard 概览
tru.get_leaderboard(app_ids=[])
# Out:
#                             Answer Relevance  Context Relevance  Groundedness  \
# app_name       app_version
# LlamaIndex_App base                      1.0           0.416667      0.833333
#
#                              latency  total_cost
# app_name       app_version
# LlamaIndex_App base         7.478883         0.0

# %%
# 启动 TruLens Dashboard，可视化查看 Automerging 引擎的评估结果
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Dashboard already running at path:   Local URL: http://localhost:55913
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>
